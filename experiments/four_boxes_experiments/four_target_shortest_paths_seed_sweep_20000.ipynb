# %% [markdown]
# # Four-target shortest paths: seed sweep at 5000 and 10000 epochs
#
# This notebook keeps the dataset, validation layouts, model architecture, and evaluation procedure fixed, and varies only the training randomness.
#
# We compare:
#
# - budgets: **5000** and **10000** epochs
# - training seeds: **0, 1, 2, 3, 4**
#
# The main quantity of interest is validation **All four visited**, summarized as mean ± standard deviation across seeds.
#
# The untouched test split is deliberately **not loaded** in this notebook, because this seed sweep is still part of model-selection / robustness analysis.

# %%
from pathlib import Path
import copy
import hashlib
import json
import random
import sys
import platform
import numpy as np
import matplotlib.pyplot as plt
import torch
from torch import nn
from IPython.display import display, Markdown

PROJECT_ROOT = Path("/home/u7779895/PycharmProjects/streaming-flow-policy")
TASK_ROOT = PROJECT_ROOT / "experiments/four_boxes_experiments/four_targets"
DATASET_DIR = TASK_ROOT / "datasets/v1"


SWEEP_ROOT = (
    TASK_ROOT
    / "runs/conditional_mlp_canonical_seed_sweep_20000"
)


SWEEP_ROOT.mkdir(
    parents=True,
    exist_ok=True,
)


# Existing seed-0 runs from the previous notebooks.
EXISTING_SEED0_DIRS = {
    5000: TASK_ROOT / "runs/conditional_mlp_canonical_5000epochs_v1_seed0",
    10000: TASK_ROOT / "runs/conditional_mlp_canonical_10000epochs_v1_seed0",
}
REUSE_EXISTING_SEED0 = False

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

required = [
    DATASET_DIR / "config.json",
    DATASET_DIR / "train.npz",
    DATASET_DIR / "validation.npz",
]
missing = [str(p) for p in required if not p.exists()]
if missing:
    raise FileNotFoundError(
        "Required existing files are missing:\n" + "\n".join(missing)
    )

splits = {}
for name in ["train", "validation"]:
    with np.load(DATASET_DIR / f"{name}.npz", allow_pickle=False) as archive:
        splits[name] = {key: archive[key].copy() for key in archive.files}

    split = splits[name]
    n = len(split["targets"])
    for key, shape in {
        "starts": (n, 2),
        "targets": (n, 4, 2),
        "conditions": (n, 10),
        "routes": (n, 5, 2),
        "knot_tau": (n, 5),
        "lengths": (n,),
    }.items():
        assert split[key].shape == shape, (name, key, split[key].shape)
        assert np.isfinite(split[key]).all(), (name, key)

    assert np.all(np.diff(split["knot_tau"], axis=1) > 0)
    np.testing.assert_allclose(split["knot_tau"][:, 0], 0)
    np.testing.assert_allclose(split["knot_tau"][:, -1], 1)
    np.testing.assert_array_equal(
        split["conditions"],
        np.concatenate(
            [split["starts"], split["targets"].reshape(n, 8)],
            axis=1,
        ),
    )
    np.testing.assert_array_equal(split["routes"][:, 0], split["starts"])

assert len(splits["train"]["targets"]) == 10_000
assert len(splits["validation"]["targets"]) == 1_000

def sha256(path):
    digest = hashlib.sha256()
    with path.open("rb") as stream:
        for block in iter(lambda: stream.read(1024 * 1024), b""):
            digest.update(block)
    return digest.hexdigest()

DATASET_SHA256 = {
    p.name: sha256(p)
    for p in required
}

BUDGETS = [20000]
SEEDS = [0, 1, 2, 3, 4]

BASE_CONFIG = {
    "input_preprocessing": "sort_targets_by_x_then_y",
    "num_training_layouts": 10_000,
    "validation_probe_seed": 500,
    "validation_probe_size": 20_000,
    "steps_per_epoch": 100,
    "batch_size": 2048,
    "learning_rate": 1e-3,
    "weight_decay": 1e-6,
    "hidden_dim": 128,
    "num_hidden_layers": 4,
    "sigma_0": 0.05,
    "stabilizing_gain": 2.5,
    "dataset_sha256": DATASET_SHA256,
}

# sample_batch() below reads CONFIG, so this global is replaced with each run's
# configuration immediately before that run is trained.
CONFIG = dict(BASE_CONFIG)

print("Device:", DEVICE)
print("Budgets:", BUDGETS)
print("Seeds:", SEEDS)
print("Layouts:", {k: len(v["targets"]) for k, v in splits.items()})
print("Sweep output:", SWEEP_ROOT)
print("Test split has not been loaded.")
# Out:
# Device: cuda
# Budgets: [20000]
# Seeds: [0, 1, 2, 3, 4]
# Layouts: {'train': 10000, 'validation': 1000}
# Sweep output: /home/u7779895/PycharmProjects/streaming-flow-policy/experiments/four_boxes_experiments/four_targets/runs/conditional_mlp_canonical_seed_sweep_20000
# Test split has not been loaded.

# %% [markdown]
# ## Reusable model and sampling definitions

# %%
def canonicalize_box_inputs(inputs):
    boxes = inputs[:, 5:].reshape(-1, 4, 2)
    for coordinate in [1, 0]:  # secondary y key, then primary x key
        order = torch.argsort(boxes[:, :, coordinate], dim=1, stable=True)
        boxes = torch.gather(boxes, 1, order.unsqueeze(-1).expand(-1, -1, 2))
    return torch.cat([inputs[:, :5], boxes.reshape(-1, 8)], dim=1)

class CanonicalConditionalVelocityMLP(nn.Module):
    def __init__(self):
        super().__init__()
        layers = []
        width = 13
        for _ in range(4):
            layers.extend([nn.Linear(width, 128), nn.SiLU()])
            width = 128
        layers.append(nn.Linear(width, 2))
        self.network = nn.Sequential(*layers)

    def forward(self, inputs):
        return self.network(2.0 * canonicalize_box_inputs(inputs) - 1.0)


def sample_batch(split, batch_size, rng):
    indices = rng.integers(0, len(split["targets"]), size=batch_size)
    tau = rng.uniform(0.0, 1.0, size=batch_size)
    routes = split["routes"][indices]
    knots = split["knot_tau"][indices]
    segments = np.clip((tau[:, None] >= knots[:, 1:]).sum(axis=1), 0, 3)
    rows = np.arange(batch_size)
    p0, p1 = routes[rows, segments], routes[rows, segments + 1]
    t0 = knots[rows, segments]
    interval = knots[rows, segments + 1] - t0
    positions = p0 + ((tau - t0) / interval)[:, None] * (p1 - p0)
    derivatives = (p1 - p0) / interval[:, None]
    offsets = (CONFIG["sigma_0"] * np.exp(-CONFIG["stabilizing_gain"] * tau))[:, None] * rng.standard_normal((batch_size, 2))
    actions = positions + offsets
    targets = derivatives - CONFIG["stabilizing_gain"] * offsets
    inputs = np.concatenate([actions, tau[:, None], split["conditions"][indices]], axis=1)
    return inputs.astype(np.float32), targets.astype(np.float32)


def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)


def atomic_save(payload, path):
    temporary = path.with_suffix(".tmp")
    torch.save(payload, temporary)
    temporary.replace(path)


@torch.no_grad()
def probe_mse(model, inputs, targets):
    model.eval()
    total = 0.0
    for offset in range(0, len(inputs), 4096):
        x, y = inputs[offset:offset+4096], targets[offset:offset+4096]
        loss = nn.functional.mse_loss(model(x), y)
        if not torch.isfinite(loss):
            raise RuntimeError("Non-finite validation loss")
        total += loss.item() * len(x)
    return total / len(inputs)

# %% [markdown]
# ## Train / resume all budget × seed runs
#
# For seed `s`, we use:
#
# - model / Python / NumPy / PyTorch seed = `s`
# - training-batch sampling seed = `1000 + s`
# - validation-probe seed = **500 for every run**
#
# Thus the dataset and validation probe stay fixed, while training randomness changes.
#
# If the earlier seed-0 5000/10000 run exists, the notebook reuses it instead of retraining it.

# %%
# ============================================================
# Train / resume seed sweep
# Cross-machine resume version
# ============================================================

# These fields are allowed to differ after moving the experiment
# to another computer.
IGNORED_CONFIG_KEYS = {
    "dataset_dir",
}


def comparable_config(config):
    """
    Remove machine-dependent fields before comparing experiment configs.
    """
    return {
        key: value
        for key, value in config.items()
        if key not in IGNORED_CONFIG_KEYS
    }


def make_run_config(budget, seed):
    cfg = dict(BASE_CONFIG)

    cfg.update({
        "experiment": f"full_dataset_canonical_budget_{budget}_seed_{seed}",
        "dataset_dir": str(DATASET_DIR),

        # Training randomness
        "training_seed": int(seed),
        "train_sampling_seed": int(1000 + seed),

        # Training budget
        "num_epochs": int(budget),
    })

    return cfg


def train_or_resume_run(budget, seed):
    global CONFIG

    # --------------------------------------------------------
    # Build config for this budget / seed
    # --------------------------------------------------------
    CONFIG = make_run_config(
        budget,
        seed,
    )

    # --------------------------------------------------------
    # Optionally reuse the old seed-0 experiments
    # --------------------------------------------------------
    if REUSE_EXISTING_SEED0 and seed == 0:

        existing_dir = EXISTING_SEED0_DIRS[budget]
        existing_best = existing_dir / "best.pt"

        if existing_best.exists():

            checkpoint = torch.load(
                existing_best,
                map_location="cpu",
                weights_only=True,
            )

            print(
                f"[reuse] {budget} epochs, seed 0 -> "
                f"epoch {checkpoint['epoch']}, "
                f"validation MSE="
                f"{checkpoint['validation_loss']:.6f}"
            )

            return existing_dir, checkpoint

    # --------------------------------------------------------
    # Directory for this run
    # --------------------------------------------------------
    run_dir = (
        SWEEP_ROOT
        / f"budget_{budget}_seed_{seed}"
    )

    run_dir.mkdir(
        parents=True,
        exist_ok=True,
    )

    # --------------------------------------------------------
    # Check config.json
    # --------------------------------------------------------
    config_path = run_dir / "config.json"

    if config_path.exists():

        existing_config = json.loads(
            config_path.read_text(
                encoding="utf-8"
            )
        )

        if (
            comparable_config(existing_config)
            != comparable_config(CONFIG)
        ):
            raise ValueError(
                f"Experiment configuration differs "
                f"from the saved run:\n"
                f"{run_dir}\n"
                f"(dataset_dir is ignored.)"
            )

    else:

        config_path.write_text(
            json.dumps(
                CONFIG,
                indent=2,
            ),
            encoding="utf-8",
        )

    # --------------------------------------------------------
    # Set random seed
    # --------------------------------------------------------
    set_seed(
        CONFIG["training_seed"]
    )

    # --------------------------------------------------------
    # Model
    # --------------------------------------------------------
    model = CanonicalConditionalVelocityMLP().to(
        device=DEVICE,
        dtype=torch.float32,
    )

    optimizer = torch.optim.AdamW(
        model.parameters(),
        lr=CONFIG["learning_rate"],
        weight_decay=CONFIG["weight_decay"],
    )

    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(
        optimizer,
        T_max=CONFIG["num_epochs"],
    )

    # --------------------------------------------------------
    # Training RNG
    # --------------------------------------------------------
    train_rng = np.random.default_rng(
        CONFIG["train_sampling_seed"]
    )

    # --------------------------------------------------------
    # Fixed validation probe
    # --------------------------------------------------------
    vx, vy = sample_batch(
        splits["validation"],
        CONFIG["validation_probe_size"],
        np.random.default_rng(
            CONFIG["validation_probe_seed"]
        ),
    )

    val_inputs = torch.from_numpy(
        vx
    ).to(DEVICE)

    val_targets = torch.from_numpy(
        vy
    ).to(DEVICE)

    # --------------------------------------------------------
    # Initial training state
    # --------------------------------------------------------
    history = {
        "train_loss": [],
        "validation_loss": [],
    }

    best_loss = float("inf")
    best_epoch = None
    start_epoch = 0

    latest_path = (
        run_dir / "latest.pt"
    )

    best_path = (
        run_dir / "best.pt"
    )

    # ========================================================
    # Resume from latest.pt if available
    # ========================================================
    if latest_path.exists():

        ckpt = torch.load(
            latest_path,
            map_location="cpu",
            weights_only=True,
        )

        # ----------------------------------------------------
        # Compare configs, ignoring machine-dependent paths
        # ----------------------------------------------------
        if (
            comparable_config(ckpt["config"])
            != comparable_config(CONFIG)
        ):
            raise ValueError(
                f"Checkpoint configuration differs "
                f"from the current experiment:\n"
                f"{latest_path}\n"
                f"(dataset_dir is ignored.)"
            )

        # ----------------------------------------------------
        # Restore model / optimizer / scheduler
        # ----------------------------------------------------
        model.load_state_dict(
            ckpt["model"]
        )

        optimizer.load_state_dict(
            ckpt["optimizer"]
        )

        scheduler.load_state_dict(
            ckpt["scheduler"]
        )

        # ----------------------------------------------------
        # Restore RNG states
        # ----------------------------------------------------
        train_rng.bit_generator.state = (
            ckpt["numpy_rng_state"]
        )

        torch.set_rng_state(
            ckpt["torch_rng_state"]
        )

        if (
            DEVICE.type == "cuda"
            and ckpt["cuda_rng_states"]
        ):
            torch.cuda.set_rng_state_all(
                ckpt["cuda_rng_states"]
            )

        # ----------------------------------------------------
        # Restore history / progress
        # ----------------------------------------------------
        history = ckpt["history"]

        best_loss = ckpt["best_loss"]

        best_epoch = ckpt["best_epoch"]

        start_epoch = ckpt["epoch"]

        print(
            f"[resume] "
            f"{budget} epochs, "
            f"seed {seed}, "
            f"after epoch {start_epoch}"
        )

    else:

        print(
            f"[new run] "
            f"{budget} epochs, "
            f"seed {seed}"
        )

    # ========================================================
    # Training loop
    # ========================================================
    for epoch in range(
        start_epoch + 1,
        CONFIG["num_epochs"] + 1,
    ):

        model.train()

        loss_sum = 0.0

        for _ in range(
            CONFIG["steps_per_epoch"]
        ):

            x, y = sample_batch(
                splits["train"],
                CONFIG["batch_size"],
                train_rng,
            )

            x = torch.from_numpy(
                x
            ).to(DEVICE)

            y = torch.from_numpy(
                y
            ).to(DEVICE)

            optimizer.zero_grad(
                set_to_none=True
            )

            prediction = model(x)

            loss = nn.functional.mse_loss(
                prediction,
                y,
            )

            if not torch.isfinite(loss):
                raise RuntimeError(
                    "Non-finite training loss"
                )

            loss.backward()

            optimizer.step()

            loss_sum += loss.item()

        # ----------------------------------------------------
        # Epoch training loss
        # ----------------------------------------------------
        train_loss = (
            loss_sum
            / CONFIG["steps_per_epoch"]
        )

        # ----------------------------------------------------
        # Validation probe
        # ----------------------------------------------------
        validation_loss = probe_mse(
            model,
            val_inputs,
            val_targets,
        )

        history["train_loss"].append(
            train_loss
        )

        history["validation_loss"].append(
            validation_loss
        )

        # ----------------------------------------------------
        # CPU copy of model state
        # ----------------------------------------------------
        state = {
            name: tensor.detach()
            .cpu()
            .clone()
            for name, tensor
            in model.state_dict().items()
        }

        # ====================================================
        # Save best checkpoint
        # ====================================================
        if validation_loss < best_loss:

            best_loss = validation_loss
            best_epoch = epoch

            atomic_save(
                {
                    "model": state,
                    "epoch": epoch,
                    "validation_loss":
                        validation_loss,
                    "config": CONFIG,
                },
                best_path,
            )

        # ----------------------------------------------------
        # Advance LR scheduler
        # ----------------------------------------------------
        scheduler.step()

        # ====================================================
        # Save latest checkpoint EVERY epoch
        # ====================================================
        atomic_save(
            {
                "model": state,

                "optimizer":
                    optimizer.state_dict(),

                "scheduler":
                    scheduler.state_dict(),

                "epoch":
                    epoch,

                "history":
                    copy.deepcopy(history),

                "best_loss":
                    best_loss,

                "best_epoch":
                    best_epoch,

                "config":
                    CONFIG,

                "numpy_rng_state":
                    train_rng.bit_generator.state,

                "torch_rng_state":
                    torch.get_rng_state(),

                "cuda_rng_states": (
                    torch.cuda.get_rng_state_all()
                    if DEVICE.type == "cuda"
                    else []
                ),
            },
            latest_path,
        )

        # ----------------------------------------------------
        # Progress output
        # ----------------------------------------------------
        if (
            epoch == 1
            or epoch % 100 == 0
            or epoch
            == CONFIG["num_epochs"]
        ):

            print(
                f"{budget:5d} ep | "
                f"seed {seed} | "
                f"epoch "
                f"{epoch:5d}/{budget} | "
                f"train="
                f"{train_loss:.6f} | "
                f"validation="
                f"{validation_loss:.6f} | "
                f"best={best_epoch}"
            )

    # ========================================================
    # Load final best checkpoint
    # ========================================================
    checkpoint = torch.load(
        best_path,
        map_location="cpu",
        weights_only=True,
    )

    # --------------------------------------------------------
    # Save training history
    # --------------------------------------------------------
    (
        run_dir / "history.json"
    ).write_text(
        json.dumps(
            history,
            indent=2,
        ),
        encoding="utf-8",
    )

    print(
        f"[done] "
        f"{budget} epochs, "
        f"seed {seed}: "
        f"selected epoch "
        f"{checkpoint['epoch']}, "
        f"validation MSE="
        f"{checkpoint['validation_loss']:.6f}"
    )

    # --------------------------------------------------------
    # Clean GPU memory before next seed
    # --------------------------------------------------------
    del (
        model,
        optimizer,
        scheduler,
        val_inputs,
        val_targets,
    )

    if DEVICE.type == "cuda":
        torch.cuda.empty_cache()

    return (
        run_dir,
        checkpoint,
    )


# ============================================================
# Run all requested budget × seed combinations
# ============================================================

run_records = {}

for budget in BUDGETS:

    for seed in SEEDS:

        print(
            "\n"
            + "=" * 80
        )

        print(
            f"Budget {budget}, "
            f"seed {seed}"
        )

        print(
            "=" * 80
        )

        run_dir, checkpoint = (
            train_or_resume_run(
                budget,
                seed,
            )
        )

        run_records[
            (budget, seed)
        ] = {
            "run_dir":
                run_dir,

            "checkpoint":
                checkpoint,
        }


print(
    "\nAll requested runs "
    "are available."
)
# Out:
# ================================================================================
# Budget 20000, seed 0
# ================================================================================
# [new run] 20000 epochs, seed 0
# 20000 ep | seed 0 | epoch     1/20000 | train=0.602732 | validation=0.514852 | best=1
# 20000 ep | seed 0 | epoch   100/20000 | train=0.064604 | validation=0.072577 | best=96
# 20000 ep | seed 0 | epoch   200/20000 | train=0.046249 | validation=0.057763 | best=197
# 20000 ep | seed 0 | epoch   300/20000 | train=0.038576 | validation=0.049535 | best=291
# 20000 ep | seed 0 | epoch   400/20000 | train=0.033871 | validation=0.046277 | best=387
# 20000 ep | seed 0 | epoch   500/20000 | train=0.031007 | validation=0.044985 | best=482
# 20000 ep | seed 0 | epoch   600/20000 | train=0.028772 | validation=0.042463 | best=596
# 20000 ep | seed 0 | epoch   700/20000 | train=0.027124 | validation=0.042060 | best=697
# 20000 ep | seed 0 | epoch   800/20000 | train=0.025272 | validation=0.040980 | best=781
# 20000 ep | seed 0 | epoch   900/20000 | train=0.025033 | validation=0.038717 | best=844
# 20000 ep | seed 0 | epoch  1000/20000 | train=0.023451 | validation=0.040177 | best=909
# 20000 ep | seed 0 | epoch  1100/20000 | train=0.023338 | validation=0.039739 | best=1081
# 20000 ep | seed 0 | epoch  1200/20000 | train=0.022231 | validation=0.038131 | best=1185
# 20000 ep | seed 0 | epoch  1300/20000 | train=0.021681 | validation=0.037449 | best=1292
# 20000 ep | seed 0 | epoch  1400/20000 | train=0.021174 | validation=0.037533 | best=1395
# 20000 ep | seed 0 | epoch  1500/20000 | train=0.019392 | validation=0.035728 | best=1447
# 20000 ep | seed 0 | epoch  1600/20000 | train=0.020459 | validation=0.036945 | best=1447
# 20000 ep | seed 0 | epoch  1700/20000 | train=0.019880 | validation=0.035621 | best=1652
# 20000 ep | seed 0 | epoch  1800/20000 | train=0.018852 | validation=0.035269 | best=1779
# 20000 ep | seed 0 | epoch  1900/20000 | train=0.018729 | validation=0.035015 | best=1779
# 20000 ep | seed 0 | epoch  2000/20000 | train=0.018701 | validation=0.036454 | best=1779
# 20000 ep | seed 0 | epoch  2100/20000 | train=0.018395 | validation=0.032303 | best=2100
# 20000 ep | seed 0 | epoch  2200/20000 | train=0.017758 | validation=0.034589 | best=2108
# 20000 ep | seed 0 | epoch  2300/20000 | train=0.017850 | validation=0.033851 | best=2108
# 20000 ep | seed 0 | epoch  2400/20000 | train=0.017838 | validation=0.033898 | best=2108
# 20000 ep | seed 0 | epoch  2500/20000 | train=0.016876 | validation=0.033558 | best=2492
# 20000 ep | seed 0 | epoch  2600/20000 | train=0.016953 | validation=0.034336 | best=2492
# 20000 ep | seed 0 | epoch  2700/20000 | train=0.016953 | validation=0.033032 | best=2492
# 20000 ep | seed 0 | epoch  2800/20000 | train=0.016811 | validation=0.032156 | best=2755
# 20000 ep | seed 0 | epoch  2900/20000 | train=0.015858 | validation=0.031803 | best=2755
# 20000 ep | seed 0 | epoch  3000/20000 | train=0.016804 | validation=0.033019 | best=2997
# 20000 ep | seed 0 | epoch  3100/20000 | train=0.016344 | validation=0.033802 | best=3042
# 20000 ep | seed 0 | epoch  3200/20000 | train=0.016222 | validation=0.032280 | best=3042
# 20000 ep | seed 0 | epoch  3300/20000 | train=0.016150 | validation=0.033332 | best=3042
# 20000 ep | seed 0 | epoch  3400/20000 | train=0.015744 | validation=0.035993 | best=3042
# 20000 ep | seed 0 | epoch  3500/20000 | train=0.015812 | validation=0.032231 | best=3042
# 20000 ep | seed 0 | epoch  3600/20000 | train=0.015173 | validation=0.033596 | best=3517
# 20000 ep | seed 0 | epoch  3700/20000 | train=0.015182 | validation=0.034687 | best=3517
# 20000 ep | seed 0 | epoch  3800/20000 | train=0.015224 | validation=0.033313 | best=3517
# 20000 ep | seed 0 | epoch  3900/20000 | train=0.015212 | validation=0.033773 | best=3517
# 20000 ep | seed 0 | epoch  4000/20000 | train=0.014870 | validation=0.033142 | best=3517
# 20000 ep | seed 0 | epoch  4100/20000 | train=0.014833 | validation=0.030867 | best=3517
# 20000 ep | seed 0 | epoch  4200/20000 | train=0.014640 | validation=0.031777 | best=3517
# 20000 ep | seed 0 | epoch  4300/20000 | train=0.014639 | validation=0.032368 | best=3517
# 20000 ep | seed 0 | epoch  4400/20000 | train=0.014059 | validation=0.031947 | best=3517
# 20000 ep | seed 0 | epoch  4500/20000 | train=0.014672 | validation=0.032285 | best=3517
# 20000 ep | seed 0 | epoch  4600/20000 | train=0.014554 | validation=0.032421 | best=3517
# 20000 ep | seed 0 | epoch  4700/20000 | train=0.014253 | validation=0.033277 | best=3517
# 20000 ep | seed 0 | epoch  4800/20000 | train=0.014505 | validation=0.032235 | best=3517
# 20000 ep | seed 0 | epoch  4900/20000 | train=0.014192 | validation=0.031910 | best=3517
# 20000 ep | seed 0 | epoch  5000/20000 | train=0.013999 | validation=0.032208 | best=3517
# 20000 ep | seed 0 | epoch  5100/20000 | train=0.014267 | validation=0.032302 | best=3517
# 20000 ep | seed 0 | epoch  5200/20000 | train=0.013803 | validation=0.032609 | best=5123
# 20000 ep | seed 0 | epoch  5300/20000 | train=0.013653 | validation=0.033085 | best=5123
# 20000 ep | seed 0 | epoch  5400/20000 | train=0.013837 | validation=0.032640 | best=5123
# 20000 ep | seed 0 | epoch  5500/20000 | train=0.013465 | validation=0.032110 | best=5123
# 20000 ep | seed 0 | epoch  5600/20000 | train=0.013141 | validation=0.032292 | best=5123
# 20000 ep | seed 0 | epoch  5700/20000 | train=0.013272 | validation=0.032421 | best=5123
# 20000 ep | seed 0 | epoch  5800/20000 | train=0.013618 | validation=0.032437 | best=5123
# 20000 ep | seed 0 | epoch  5900/20000 | train=0.012969 | validation=0.032235 | best=5123
# 20000 ep | seed 0 | epoch  6000/20000 | train=0.013636 | validation=0.031533 | best=5123
# 20000 ep | seed 0 | epoch  6100/20000 | train=0.012950 | validation=0.031425 | best=5123
# 20000 ep | seed 0 | epoch  6200/20000 | train=0.013223 | validation=0.032183 | best=5123
# 20000 ep | seed 0 | epoch  6300/20000 | train=0.012726 | validation=0.031569 | best=5123
# 20000 ep | seed 0 | epoch  6400/20000 | train=0.012714 | validation=0.032088 | best=5123
# 20000 ep | seed 0 | epoch  6500/20000 | train=0.012960 | validation=0.031906 | best=5123
# 20000 ep | seed 0 | epoch  6600/20000 | train=0.012673 | validation=0.031840 | best=6550
# 20000 ep | seed 0 | epoch  6700/20000 | train=0.013029 | validation=0.031665 | best=6550
# 20000 ep | seed 0 | epoch  6800/20000 | train=0.012475 | validation=0.032345 | best=6550
# 20000 ep | seed 0 | epoch  6900/20000 | train=0.012096 | validation=0.031041 | best=6550
# 20000 ep | seed 0 | epoch  7000/20000 | train=0.012551 | validation=0.031970 | best=6550
# 20000 ep | seed 0 | epoch  7100/20000 | train=0.012318 | validation=0.031410 | best=6550
# 20000 ep | seed 0 | epoch  7200/20000 | train=0.012461 | validation=0.032393 | best=6550
# 20000 ep | seed 0 | epoch  7300/20000 | train=0.012216 | validation=0.031517 | best=6550
# 20000 ep | seed 0 | epoch  7400/20000 | train=0.012381 | validation=0.031934 | best=6550
# 20000 ep | seed 0 | epoch  7500/20000 | train=0.011949 | validation=0.031767 | best=6550
# 20000 ep | seed 0 | epoch  7600/20000 | train=0.011747 | validation=0.032257 | best=6550
# 20000 ep | seed 0 | epoch  7700/20000 | train=0.011732 | validation=0.031813 | best=6550
# 20000 ep | seed 0 | epoch  7800/20000 | train=0.012261 | validation=0.032399 | best=6550
# 20000 ep | seed 0 | epoch  7900/20000 | train=0.012016 | validation=0.031230 | best=6550
# 20000 ep | seed 0 | epoch  8000/20000 | train=0.011822 | validation=0.031989 | best=6550
# 20000 ep | seed 0 | epoch  8100/20000 | train=0.012092 | validation=0.031906 | best=6550
# 20000 ep | seed 0 | epoch  8200/20000 | train=0.012114 | validation=0.031431 | best=6550
# 20000 ep | seed 0 | epoch  8300/20000 | train=0.011323 | validation=0.032166 | best=6550
# 20000 ep | seed 0 | epoch  8400/20000 | train=0.012037 | validation=0.031374 | best=6550
# 20000 ep | seed 0 | epoch  8500/20000 | train=0.011659 | validation=0.032154 | best=6550
# 20000 ep | seed 0 | epoch  8600/20000 | train=0.011123 | validation=0.031547 | best=6550
# 20000 ep | seed 0 | epoch  8700/20000 | train=0.011497 | validation=0.033574 | best=6550
# 20000 ep | seed 0 | epoch  8800/20000 | train=0.011381 | validation=0.031020 | best=6550
# 20000 ep | seed 0 | epoch  8900/20000 | train=0.011453 | validation=0.032429 | best=6550
# 20000 ep | seed 0 | epoch  9000/20000 | train=0.011378 | validation=0.032862 | best=6550
# 20000 ep | seed 0 | epoch  9100/20000 | train=0.011016 | validation=0.032201 | best=6550
# 20000 ep | seed 0 | epoch  9200/20000 | train=0.011040 | validation=0.032182 | best=6550
# 20000 ep | seed 0 | epoch  9300/20000 | train=0.010637 | validation=0.032524 | best=6550
# 20000 ep | seed 0 | epoch  9400/20000 | train=0.011488 | validation=0.032275 | best=6550
# 20000 ep | seed 0 | epoch  9500/20000 | train=0.011238 | validation=0.031695 | best=6550
# 20000 ep | seed 0 | epoch  9600/20000 | train=0.010902 | validation=0.032434 | best=6550
# 20000 ep | seed 0 | epoch  9700/20000 | train=0.010865 | validation=0.033039 | best=6550
# 20000 ep | seed 0 | epoch  9800/20000 | train=0.010895 | validation=0.032743 | best=6550
# 20000 ep | seed 0 | epoch  9900/20000 | train=0.011174 | validation=0.032141 | best=6550
# 20000 ep | seed 0 | epoch 10000/20000 | train=0.011073 | validation=0.032356 | best=6550
# 20000 ep | seed 0 | epoch 10100/20000 | train=0.010590 | validation=0.032549 | best=6550
# 20000 ep | seed 0 | epoch 10200/20000 | train=0.011060 | validation=0.031276 | best=6550
# 20000 ep | seed 0 | epoch 10300/20000 | train=0.010791 | validation=0.032615 | best=6550
# 20000 ep | seed 0 | epoch 10400/20000 | train=0.010605 | validation=0.032085 | best=6550
# 20000 ep | seed 0 | epoch 10500/20000 | train=0.010432 | validation=0.031896 | best=6550
# 20000 ep | seed 0 | epoch 10600/20000 | train=0.010500 | validation=0.032508 | best=6550
# 20000 ep | seed 0 | epoch 10700/20000 | train=0.010055 | validation=0.031900 | best=6550
# 20000 ep | seed 0 | epoch 10800/20000 | train=0.010748 | validation=0.031691 | best=6550
# 20000 ep | seed 0 | epoch 10900/20000 | train=0.009986 | validation=0.031848 | best=6550
# 20000 ep | seed 0 | epoch 11000/20000 | train=0.010346 | validation=0.033167 | best=6550
# 20000 ep | seed 0 | epoch 11100/20000 | train=0.010032 | validation=0.032697 | best=6550
# 20000 ep | seed 0 | epoch 11200/20000 | train=0.010044 | validation=0.031774 | best=6550
# 20000 ep | seed 0 | epoch 11300/20000 | train=0.010144 | validation=0.032423 | best=6550
# 20000 ep | seed 0 | epoch 11400/20000 | train=0.009961 | validation=0.032742 | best=6550
# 20000 ep | seed 0 | epoch 11500/20000 | train=0.009821 | validation=0.031905 | best=6550
# 20000 ep | seed 0 | epoch 11600/20000 | train=0.009658 | validation=0.031661 | best=6550
# 20000 ep | seed 0 | epoch 11700/20000 | train=0.009817 | validation=0.033111 | best=6550
# 20000 ep | seed 0 | epoch 11800/20000 | train=0.009688 | validation=0.032734 | best=6550
# 20000 ep | seed 0 | epoch 11900/20000 | train=0.009829 | validation=0.032428 | best=6550
# 20000 ep | seed 0 | epoch 12000/20000 | train=0.009939 | validation=0.032598 | best=6550
# 20000 ep | seed 0 | epoch 12100/20000 | train=0.009769 | validation=0.032789 | best=6550
# 20000 ep | seed 0 | epoch 12200/20000 | train=0.009633 | validation=0.032487 | best=6550
# 20000 ep | seed 0 | epoch 12300/20000 | train=0.009615 | validation=0.032757 | best=6550
# 20000 ep | seed 0 | epoch 12400/20000 | train=0.009308 | validation=0.032308 | best=6550
# 20000 ep | seed 0 | epoch 12500/20000 | train=0.009269 | validation=0.032280 | best=6550
# 20000 ep | seed 0 | epoch 12600/20000 | train=0.009573 | validation=0.031975 | best=6550
# 20000 ep | seed 0 | epoch 12700/20000 | train=0.009440 | validation=0.032179 | best=6550
# 20000 ep | seed 0 | epoch 12800/20000 | train=0.009303 | validation=0.031722 | best=6550
# 20000 ep | seed 0 | epoch 12900/20000 | train=0.009318 | validation=0.032572 | best=6550
# 20000 ep | seed 0 | epoch 13000/20000 | train=0.009244 | validation=0.032180 | best=6550
# 20000 ep | seed 0 | epoch 13100/20000 | train=0.009252 | validation=0.032050 | best=6550
# 20000 ep | seed 0 | epoch 13200/20000 | train=0.009324 | validation=0.032473 | best=6550
# 20000 ep | seed 0 | epoch 13300/20000 | train=0.009131 | validation=0.033300 | best=6550
# 20000 ep | seed 0 | epoch 13400/20000 | train=0.008989 | validation=0.032413 | best=6550
# 20000 ep | seed 0 | epoch 13500/20000 | train=0.009233 | validation=0.033065 | best=6550
# 20000 ep | seed 0 | epoch 13600/20000 | train=0.009409 | validation=0.032270 | best=6550
# 20000 ep | seed 0 | epoch 13700/20000 | train=0.009340 | validation=0.032621 | best=6550
# 20000 ep | seed 0 | epoch 13800/20000 | train=0.008919 | validation=0.032601 | best=6550
# 20000 ep | seed 0 | epoch 13900/20000 | train=0.009036 | validation=0.032783 | best=6550
# 20000 ep | seed 0 | epoch 14000/20000 | train=0.008618 | validation=0.033255 | best=6550
# 20000 ep | seed 0 | epoch 14100/20000 | train=0.008744 | validation=0.032488 | best=6550
# 20000 ep | seed 0 | epoch 14200/20000 | train=0.009214 | validation=0.033246 | best=6550
# 20000 ep | seed 0 | epoch 14300/20000 | train=0.008705 | validation=0.032761 | best=6550
# 20000 ep | seed 0 | epoch 14400/20000 | train=0.008930 | validation=0.032300 | best=6550
# 20000 ep | seed 0 | epoch 14500/20000 | train=0.008687 | validation=0.032275 | best=6550
# 20000 ep | seed 0 | epoch 14600/20000 | train=0.008819 | validation=0.032604 | best=6550
# 20000 ep | seed 0 | epoch 14700/20000 | train=0.008560 | validation=0.032728 | best=6550
# 20000 ep | seed 0 | epoch 14800/20000 | train=0.008417 | validation=0.032489 | best=6550
# 20000 ep | seed 0 | epoch 14900/20000 | train=0.008605 | validation=0.032305 | best=6550
# 20000 ep | seed 0 | epoch 15000/20000 | train=0.008838 | validation=0.033207 | best=6550
# 20000 ep | seed 0 | epoch 15100/20000 | train=0.008421 | validation=0.032481 | best=6550
# 20000 ep | seed 0 | epoch 15200/20000 | train=0.008700 | validation=0.033644 | best=6550
# 20000 ep | seed 0 | epoch 15300/20000 | train=0.008342 | validation=0.032412 | best=6550
# 20000 ep | seed 0 | epoch 15400/20000 | train=0.008683 | validation=0.032588 | best=6550
# 20000 ep | seed 0 | epoch 15500/20000 | train=0.008214 | validation=0.033206 | best=6550
# 20000 ep | seed 0 | epoch 15600/20000 | train=0.008485 | validation=0.032709 | best=6550
# 20000 ep | seed 0 | epoch 15700/20000 | train=0.008404 | validation=0.032994 | best=6550
# 20000 ep | seed 0 | epoch 15800/20000 | train=0.008474 | validation=0.033004 | best=6550
# 20000 ep | seed 0 | epoch 15900/20000 | train=0.008141 | validation=0.033113 | best=6550
# 20000 ep | seed 0 | epoch 16000/20000 | train=0.008409 | validation=0.032539 | best=6550
# 20000 ep | seed 0 | epoch 16100/20000 | train=0.008126 | validation=0.032722 | best=6550
# 20000 ep | seed 0 | epoch 16200/20000 | train=0.008366 | validation=0.033476 | best=6550
# 20000 ep | seed 0 | epoch 16300/20000 | train=0.008377 | validation=0.032947 | best=6550
# 20000 ep | seed 0 | epoch 16400/20000 | train=0.008036 | validation=0.032875 | best=6550
# 20000 ep | seed 0 | epoch 16500/20000 | train=0.008292 | validation=0.033124 | best=6550
# 20000 ep | seed 0 | epoch 16600/20000 | train=0.008357 | validation=0.033025 | best=6550
# 20000 ep | seed 0 | epoch 16700/20000 | train=0.008167 | validation=0.032472 | best=6550
# 20000 ep | seed 0 | epoch 16800/20000 | train=0.007913 | validation=0.032904 | best=6550
# 20000 ep | seed 0 | epoch 16900/20000 | train=0.008159 | validation=0.032974 | best=6550
# 20000 ep | seed 0 | epoch 17000/20000 | train=0.008126 | validation=0.032672 | best=6550
# 20000 ep | seed 0 | epoch 17100/20000 | train=0.008135 | validation=0.032890 | best=6550
# 20000 ep | seed 0 | epoch 17200/20000 | train=0.008284 | validation=0.033319 | best=6550
# 20000 ep | seed 0 | epoch 17300/20000 | train=0.008015 | validation=0.032617 | best=6550
# 20000 ep | seed 0 | epoch 17400/20000 | train=0.008050 | validation=0.032620 | best=6550
# 20000 ep | seed 0 | epoch 17500/20000 | train=0.008352 | validation=0.033238 | best=6550
# 20000 ep | seed 0 | epoch 17600/20000 | train=0.008080 | validation=0.032843 | best=6550
# 20000 ep | seed 0 | epoch 17700/20000 | train=0.008116 | validation=0.033299 | best=6550
# 20000 ep | seed 0 | epoch 17800/20000 | train=0.007971 | validation=0.032847 | best=6550
# 20000 ep | seed 0 | epoch 17900/20000 | train=0.008180 | validation=0.032835 | best=6550
# 20000 ep | seed 0 | epoch 18000/20000 | train=0.008148 | validation=0.033039 | best=6550
# 20000 ep | seed 0 | epoch 18100/20000 | train=0.008110 | validation=0.032975 | best=6550
# 20000 ep | seed 0 | epoch 18200/20000 | train=0.008130 | validation=0.032992 | best=6550
# 20000 ep | seed 0 | epoch 18300/20000 | train=0.007896 | validation=0.033110 | best=6550
# 20000 ep | seed 0 | epoch 18400/20000 | train=0.007978 | validation=0.033083 | best=6550
# 20000 ep | seed 0 | epoch 18500/20000 | train=0.007785 | validation=0.032947 | best=6550
# 20000 ep | seed 0 | epoch 18600/20000 | train=0.007807 | validation=0.033127 | best=6550
# 20000 ep | seed 0 | epoch 18700/20000 | train=0.008094 | validation=0.032956 | best=6550
# 20000 ep | seed 0 | epoch 18800/20000 | train=0.007667 | validation=0.033036 | best=6550
# 20000 ep | seed 0 | epoch 18900/20000 | train=0.007841 | validation=0.033047 | best=6550
# 20000 ep | seed 0 | epoch 19000/20000 | train=0.007877 | validation=0.033035 | best=6550
# 20000 ep | seed 0 | epoch 19100/20000 | train=0.008056 | validation=0.033049 | best=6550
# 20000 ep | seed 0 | epoch 19200/20000 | train=0.007977 | validation=0.032937 | best=6550
# 20000 ep | seed 0 | epoch 19300/20000 | train=0.008007 | validation=0.032897 | best=6550
# 20000 ep | seed 0 | epoch 19400/20000 | train=0.008126 | validation=0.032939 | best=6550
# 20000 ep | seed 0 | epoch 19500/20000 | train=0.008196 | validation=0.033009 | best=6550
# 20000 ep | seed 0 | epoch 19600/20000 | train=0.007835 | validation=0.032993 | best=6550
# 20000 ep | seed 0 | epoch 19700/20000 | train=0.007732 | validation=0.032977 | best=6550
# 20000 ep | seed 0 | epoch 19800/20000 | train=0.007761 | validation=0.033014 | best=6550
# 20000 ep | seed 0 | epoch 19900/20000 | train=0.007564 | validation=0.032996 | best=6550
# 20000 ep | seed 0 | epoch 20000/20000 | train=0.007891 | validation=0.032997 | best=6550
# [done] 20000 epochs, seed 0: selected epoch 6550, validation MSE=0.029689
#
# ================================================================================
# Budget 20000, seed 1
# ================================================================================
# [new run] 20000 epochs, seed 1
# 20000 ep | seed 1 | epoch     1/20000 | train=0.609808 | validation=0.530438 | best=1
# 20000 ep | seed 1 | epoch   100/20000 | train=0.069722 | validation=0.075985 | best=100
# 20000 ep | seed 1 | epoch   200/20000 | train=0.048818 | validation=0.057972 | best=197
# 20000 ep | seed 1 | epoch   300/20000 | train=0.038604 | validation=0.050172 | best=294
# 20000 ep | seed 1 | epoch   400/20000 | train=0.033779 | validation=0.046396 | best=394
# 20000 ep | seed 1 | epoch   500/20000 | train=0.030281 | validation=0.042786 | best=500
# 20000 ep | seed 1 | epoch   600/20000 | train=0.028205 | validation=0.043067 | best=596
# 20000 ep | seed 1 | epoch   700/20000 | train=0.027180 | validation=0.042720 | best=670
# 20000 ep | seed 1 | epoch   800/20000 | train=0.024935 | validation=0.040890 | best=746
# 20000 ep | seed 1 | epoch   900/20000 | train=0.023900 | validation=0.039443 | best=888
# 20000 ep | seed 1 | epoch  1000/20000 | train=0.022743 | validation=0.039112 | best=903
# 20000 ep | seed 1 | epoch  1100/20000 | train=0.021938 | validation=0.037342 | best=1035
# 20000 ep | seed 1 | epoch  1200/20000 | train=0.021837 | validation=0.038850 | best=1166
# 20000 ep | seed 1 | epoch  1300/20000 | train=0.021249 | validation=0.038137 | best=1250
# 20000 ep | seed 1 | epoch  1400/20000 | train=0.020479 | validation=0.037451 | best=1377
# 20000 ep | seed 1 | epoch  1500/20000 | train=0.019785 | validation=0.037341 | best=1495
# 20000 ep | seed 1 | epoch  1600/20000 | train=0.019393 | validation=0.037499 | best=1551
# 20000 ep | seed 1 | epoch  1700/20000 | train=0.019033 | validation=0.036357 | best=1551
# 20000 ep | seed 1 | epoch  1800/20000 | train=0.019097 | validation=0.037800 | best=1551
# 20000 ep | seed 1 | epoch  1900/20000 | train=0.018349 | validation=0.035250 | best=1551
# 20000 ep | seed 1 | epoch  2000/20000 | train=0.018760 | validation=0.036898 | best=1551
# 20000 ep | seed 1 | epoch  2100/20000 | train=0.018609 | validation=0.034909 | best=2073
# 20000 ep | seed 1 | epoch  2200/20000 | train=0.017941 | validation=0.034216 | best=2073
# 20000 ep | seed 1 | epoch  2300/20000 | train=0.018208 | validation=0.035749 | best=2073
# 20000 ep | seed 1 | epoch  2400/20000 | train=0.017855 | validation=0.034713 | best=2376
# 20000 ep | seed 1 | epoch  2500/20000 | train=0.017145 | validation=0.036901 | best=2376
# 20000 ep | seed 1 | epoch  2600/20000 | train=0.017015 | validation=0.034004 | best=2376
# 20000 ep | seed 1 | epoch  2700/20000 | train=0.016469 | validation=0.035747 | best=2376
# 20000 ep | seed 1 | epoch  2800/20000 | train=0.016521 | validation=0.034478 | best=2376
# 20000 ep | seed 1 | epoch  2900/20000 | train=0.016876 | validation=0.033230 | best=2376
# 20000 ep | seed 1 | epoch  3000/20000 | train=0.016662 | validation=0.034701 | best=2909
# 20000 ep | seed 1 | epoch  3100/20000 | train=0.016120 | validation=0.033356 | best=2909
# 20000 ep | seed 1 | epoch  3200/20000 | train=0.015990 | validation=0.034111 | best=2909
# 20000 ep | seed 1 | epoch  3300/20000 | train=0.015609 | validation=0.034633 | best=2909
# 20000 ep | seed 1 | epoch  3400/20000 | train=0.015495 | validation=0.033261 | best=2909
# 20000 ep | seed 1 | epoch  3500/20000 | train=0.015330 | validation=0.034756 | best=3466
# 20000 ep | seed 1 | epoch  3600/20000 | train=0.015425 | validation=0.034492 | best=3466
# 20000 ep | seed 1 | epoch  3700/20000 | train=0.014988 | validation=0.034418 | best=3466
# 20000 ep | seed 1 | epoch  3800/20000 | train=0.015144 | validation=0.035917 | best=3466
# 20000 ep | seed 1 | epoch  3900/20000 | train=0.014735 | validation=0.035347 | best=3826
# 20000 ep | seed 1 | epoch  4000/20000 | train=0.014391 | validation=0.033961 | best=3826
# 20000 ep | seed 1 | epoch  4100/20000 | train=0.014366 | validation=0.034102 | best=3826
# 20000 ep | seed 1 | epoch  4200/20000 | train=0.014532 | validation=0.035085 | best=3826
# 20000 ep | seed 1 | epoch  4300/20000 | train=0.014293 | validation=0.035275 | best=4299
# 20000 ep | seed 1 | epoch  4400/20000 | train=0.013994 | validation=0.035187 | best=4299
# 20000 ep | seed 1 | epoch  4500/20000 | train=0.014381 | validation=0.034882 | best=4299
# 20000 ep | seed 1 | epoch  4600/20000 | train=0.014297 | validation=0.034835 | best=4299
# 20000 ep | seed 1 | epoch  4700/20000 | train=0.013862 | validation=0.034710 | best=4299
# 20000 ep | seed 1 | epoch  4800/20000 | train=0.013869 | validation=0.034283 | best=4299
# 20000 ep | seed 1 | epoch  4900/20000 | train=0.014077 | validation=0.034852 | best=4299
# 20000 ep | seed 1 | epoch  5000/20000 | train=0.013932 | validation=0.034568 | best=4299
# 20000 ep | seed 1 | epoch  5100/20000 | train=0.014223 | validation=0.034463 | best=4299
# 20000 ep | seed 1 | epoch  5200/20000 | train=0.014077 | validation=0.034588 | best=4299
# 20000 ep | seed 1 | epoch  5300/20000 | train=0.013528 | validation=0.033094 | best=4299
# 20000 ep | seed 1 | epoch  5400/20000 | train=0.013719 | validation=0.034757 | best=4299
# 20000 ep | seed 1 | epoch  5500/20000 | train=0.013511 | validation=0.034846 | best=4299
# 20000 ep | seed 1 | epoch  5600/20000 | train=0.013156 | validation=0.033811 | best=4299
# 20000 ep | seed 1 | epoch  5700/20000 | train=0.013807 | validation=0.033838 | best=4299
# 20000 ep | seed 1 | epoch  5800/20000 | train=0.013593 | validation=0.033487 | best=4299
# 20000 ep | seed 1 | epoch  5900/20000 | train=0.012917 | validation=0.033787 | best=4299
# 20000 ep | seed 1 | epoch  6000/20000 | train=0.012350 | validation=0.034019 | best=4299
# 20000 ep | seed 1 | epoch  6100/20000 | train=0.012871 | validation=0.034074 | best=4299
# 20000 ep | seed 1 | epoch  6200/20000 | train=0.012794 | validation=0.033638 | best=4299
# 20000 ep | seed 1 | epoch  6300/20000 | train=0.012594 | validation=0.034700 | best=4299
# 20000 ep | seed 1 | epoch  6400/20000 | train=0.012668 | validation=0.033191 | best=4299
# 20000 ep | seed 1 | epoch  6500/20000 | train=0.012544 | validation=0.034215 | best=4299
# 20000 ep | seed 1 | epoch  6600/20000 | train=0.012705 | validation=0.033849 | best=4299
# 20000 ep | seed 1 | epoch  6700/20000 | train=0.012399 | validation=0.032253 | best=4299
# 20000 ep | seed 1 | epoch  6800/20000 | train=0.011981 | validation=0.034185 | best=4299
# 20000 ep | seed 1 | epoch  6900/20000 | train=0.012720 | validation=0.033665 | best=4299
# 20000 ep | seed 1 | epoch  7000/20000 | train=0.012419 | validation=0.033208 | best=4299
# 20000 ep | seed 1 | epoch  7100/20000 | train=0.012673 | validation=0.034404 | best=4299
# 20000 ep | seed 1 | epoch  7200/20000 | train=0.012090 | validation=0.032892 | best=4299
# 20000 ep | seed 1 | epoch  7300/20000 | train=0.012197 | validation=0.033861 | best=4299
# 20000 ep | seed 1 | epoch  7400/20000 | train=0.011948 | validation=0.032580 | best=7362
# 20000 ep | seed 1 | epoch  7500/20000 | train=0.011936 | validation=0.035042 | best=7362
# 20000 ep | seed 1 | epoch  7600/20000 | train=0.011782 | validation=0.032615 | best=7559
# 20000 ep | seed 1 | epoch  7700/20000 | train=0.011758 | validation=0.034801 | best=7640
# 20000 ep | seed 1 | epoch  7800/20000 | train=0.011984 | validation=0.033125 | best=7640
# 20000 ep | seed 1 | epoch  7900/20000 | train=0.011792 | validation=0.032481 | best=7640
# 20000 ep | seed 1 | epoch  8000/20000 | train=0.011565 | validation=0.033499 | best=7640
# 20000 ep | seed 1 | epoch  8100/20000 | train=0.011326 | validation=0.033239 | best=7640
# 20000 ep | seed 1 | epoch  8200/20000 | train=0.011542 | validation=0.032961 | best=7640
# 20000 ep | seed 1 | epoch  8300/20000 | train=0.011466 | validation=0.032511 | best=8220
# 20000 ep | seed 1 | epoch  8400/20000 | train=0.011506 | validation=0.032317 | best=8220
# 20000 ep | seed 1 | epoch  8500/20000 | train=0.011312 | validation=0.033909 | best=8220
# 20000 ep | seed 1 | epoch  8600/20000 | train=0.011510 | validation=0.031924 | best=8516
# 20000 ep | seed 1 | epoch  8700/20000 | train=0.011114 | validation=0.032491 | best=8516
# 20000 ep | seed 1 | epoch  8800/20000 | train=0.011058 | validation=0.032581 | best=8516
# 20000 ep | seed 1 | epoch  8900/20000 | train=0.011122 | validation=0.031272 | best=8516
# 20000 ep | seed 1 | epoch  9000/20000 | train=0.011117 | validation=0.032906 | best=8516
# 20000 ep | seed 1 | epoch  9100/20000 | train=0.010920 | validation=0.032529 | best=8516
# 20000 ep | seed 1 | epoch  9200/20000 | train=0.010877 | validation=0.031994 | best=8516
# 20000 ep | seed 1 | epoch  9300/20000 | train=0.010774 | validation=0.032549 | best=9246
# 20000 ep | seed 1 | epoch  9400/20000 | train=0.010587 | validation=0.031892 | best=9246
# 20000 ep | seed 1 | epoch  9500/20000 | train=0.010742 | validation=0.032417 | best=9246
# 20000 ep | seed 1 | epoch  9600/20000 | train=0.010797 | validation=0.031898 | best=9246
# 20000 ep | seed 1 | epoch  9700/20000 | train=0.010540 | validation=0.033117 | best=9246
# 20000 ep | seed 1 | epoch  9800/20000 | train=0.010678 | validation=0.032192 | best=9775
# 20000 ep | seed 1 | epoch  9900/20000 | train=0.010706 | validation=0.031856 | best=9808
# 20000 ep | seed 1 | epoch 10000/20000 | train=0.010719 | validation=0.033408 | best=9808
# 20000 ep | seed 1 | epoch 10100/20000 | train=0.010527 | validation=0.032310 | best=9808
# 20000 ep | seed 1 | epoch 10200/20000 | train=0.010454 | validation=0.031789 | best=9808
# 20000 ep | seed 1 | epoch 10300/20000 | train=0.010028 | validation=0.033284 | best=10243
# 20000 ep | seed 1 | epoch 10400/20000 | train=0.010634 | validation=0.032541 | best=10243
# 20000 ep | seed 1 | epoch 10500/20000 | train=0.010540 | validation=0.031530 | best=10419
# 20000 ep | seed 1 | epoch 10600/20000 | train=0.010319 | validation=0.032333 | best=10419
# 20000 ep | seed 1 | epoch 10700/20000 | train=0.010422 | validation=0.031813 | best=10419
# 20000 ep | seed 1 | epoch 10800/20000 | train=0.010440 | validation=0.032644 | best=10419
# 20000 ep | seed 1 | epoch 10900/20000 | train=0.009843 | validation=0.033092 | best=10419
# 20000 ep | seed 1 | epoch 11000/20000 | train=0.009896 | validation=0.032874 | best=10419
# 20000 ep | seed 1 | epoch 11100/20000 | train=0.009859 | validation=0.032767 | best=10419
# 20000 ep | seed 1 | epoch 11200/20000 | train=0.009809 | validation=0.031921 | best=10419
# 20000 ep | seed 1 | epoch 11300/20000 | train=0.009858 | validation=0.033143 | best=10419
# 20000 ep | seed 1 | epoch 11400/20000 | train=0.010040 | validation=0.031565 | best=10419
# 20000 ep | seed 1 | epoch 11500/20000 | train=0.009640 | validation=0.032985 | best=10419
# 20000 ep | seed 1 | epoch 11600/20000 | train=0.009596 | validation=0.032268 | best=10419
# 20000 ep | seed 1 | epoch 11700/20000 | train=0.010149 | validation=0.032168 | best=10419
# 20000 ep | seed 1 | epoch 11800/20000 | train=0.009632 | validation=0.031830 | best=10419
# 20000 ep | seed 1 | epoch 11900/20000 | train=0.009798 | validation=0.032230 | best=10419
# 20000 ep | seed 1 | epoch 12000/20000 | train=0.009527 | validation=0.032458 | best=10419
# 20000 ep | seed 1 | epoch 12100/20000 | train=0.009508 | validation=0.032285 | best=10419
# 20000 ep | seed 1 | epoch 12200/20000 | train=0.009720 | validation=0.033206 | best=10419
# 20000 ep | seed 1 | epoch 12300/20000 | train=0.009808 | validation=0.032052 | best=10419
# 20000 ep | seed 1 | epoch 12400/20000 | train=0.009585 | validation=0.032490 | best=10419
# 20000 ep | seed 1 | epoch 12500/20000 | train=0.009257 | validation=0.032392 | best=10419
# 20000 ep | seed 1 | epoch 12600/20000 | train=0.009487 | validation=0.032457 | best=10419
# 20000 ep | seed 1 | epoch 12700/20000 | train=0.009347 | validation=0.033019 | best=10419
# 20000 ep | seed 1 | epoch 12800/20000 | train=0.009265 | validation=0.032717 | best=10419
# 20000 ep | seed 1 | epoch 12900/20000 | train=0.008912 | validation=0.032900 | best=10419
# 20000 ep | seed 1 | epoch 13000/20000 | train=0.009138 | validation=0.032492 | best=10419
# 20000 ep | seed 1 | epoch 13100/20000 | train=0.009333 | validation=0.033362 | best=10419
# 20000 ep | seed 1 | epoch 13200/20000 | train=0.009260 | validation=0.033138 | best=10419
# 20000 ep | seed 1 | epoch 13300/20000 | train=0.009116 | validation=0.033075 | best=10419
# 20000 ep | seed 1 | epoch 13400/20000 | train=0.009268 | validation=0.033223 | best=10419
# 20000 ep | seed 1 | epoch 13500/20000 | train=0.009148 | validation=0.031886 | best=10419
# 20000 ep | seed 1 | epoch 13600/20000 | train=0.009221 | validation=0.032851 | best=10419
# 20000 ep | seed 1 | epoch 13700/20000 | train=0.009343 | validation=0.033420 | best=10419
# 20000 ep | seed 1 | epoch 13800/20000 | train=0.009024 | validation=0.032293 | best=10419
# 20000 ep | seed 1 | epoch 13900/20000 | train=0.008753 | validation=0.032983 | best=10419
# 20000 ep | seed 1 | epoch 14000/20000 | train=0.008663 | validation=0.032527 | best=10419
# 20000 ep | seed 1 | epoch 14100/20000 | train=0.008998 | validation=0.031648 | best=10419
# 20000 ep | seed 1 | epoch 14200/20000 | train=0.008549 | validation=0.032769 | best=10419
# 20000 ep | seed 1 | epoch 14300/20000 | train=0.009002 | validation=0.033115 | best=10419
# 20000 ep | seed 1 | epoch 14400/20000 | train=0.008716 | validation=0.032588 | best=10419
# 20000 ep | seed 1 | epoch 14500/20000 | train=0.008551 | validation=0.032578 | best=10419
# 20000 ep | seed 1 | epoch 14600/20000 | train=0.008653 | validation=0.032864 | best=10419
# 20000 ep | seed 1 | epoch 14700/20000 | train=0.008546 | validation=0.032599 | best=10419
# 20000 ep | seed 1 | epoch 14800/20000 | train=0.008730 | validation=0.032144 | best=10419
# 20000 ep | seed 1 | epoch 14900/20000 | train=0.008494 | validation=0.031722 | best=10419
# 20000 ep | seed 1 | epoch 15000/20000 | train=0.008697 | validation=0.032335 | best=10419
# 20000 ep | seed 1 | epoch 15100/20000 | train=0.008253 | validation=0.032748 | best=10419
# 20000 ep | seed 1 | epoch 15200/20000 | train=0.008679 | validation=0.032357 | best=10419
# 20000 ep | seed 1 | epoch 15300/20000 | train=0.008301 | validation=0.032977 | best=10419
# 20000 ep | seed 1 | epoch 15400/20000 | train=0.008338 | validation=0.033198 | best=10419
# 20000 ep | seed 1 | epoch 15500/20000 | train=0.008229 | validation=0.032779 | best=10419
# 20000 ep | seed 1 | epoch 15600/20000 | train=0.008548 | validation=0.032965 | best=10419
# 20000 ep | seed 1 | epoch 15700/20000 | train=0.008340 | validation=0.032463 | best=10419
# 20000 ep | seed 1 | epoch 15800/20000 | train=0.008453 | validation=0.032654 | best=10419
# 20000 ep | seed 1 | epoch 15900/20000 | train=0.008055 | validation=0.032813 | best=10419
# 20000 ep | seed 1 | epoch 16000/20000 | train=0.008243 | validation=0.032366 | best=10419
# 20000 ep | seed 1 | epoch 16100/20000 | train=0.008537 | validation=0.032057 | best=10419
# 20000 ep | seed 1 | epoch 16200/20000 | train=0.008064 | validation=0.032668 | best=10419
# 20000 ep | seed 1 | epoch 16300/20000 | train=0.008339 | validation=0.032890 | best=10419
# 20000 ep | seed 1 | epoch 16400/20000 | train=0.008212 | validation=0.032857 | best=10419
# 20000 ep | seed 1 | epoch 16500/20000 | train=0.008050 | validation=0.033031 | best=10419
# 20000 ep | seed 1 | epoch 16600/20000 | train=0.008062 | validation=0.033162 | best=10419
# 20000 ep | seed 1 | epoch 16700/20000 | train=0.008109 | validation=0.032682 | best=10419
# 20000 ep | seed 1 | epoch 16800/20000 | train=0.008065 | validation=0.032211 | best=10419
# 20000 ep | seed 1 | epoch 16900/20000 | train=0.007894 | validation=0.032831 | best=10419
# 20000 ep | seed 1 | epoch 17000/20000 | train=0.008099 | validation=0.033153 | best=10419
# 20000 ep | seed 1 | epoch 17100/20000 | train=0.008085 | validation=0.032500 | best=10419
# 20000 ep | seed 1 | epoch 17200/20000 | train=0.007854 | validation=0.032682 | best=10419
# 20000 ep | seed 1 | epoch 17300/20000 | train=0.008229 | validation=0.032410 | best=10419
# 20000 ep | seed 1 | epoch 17400/20000 | train=0.007948 | validation=0.032456 | best=10419
# 20000 ep | seed 1 | epoch 17500/20000 | train=0.007833 | validation=0.032441 | best=10419
# 20000 ep | seed 1 | epoch 17600/20000 | train=0.007551 | validation=0.032979 | best=10419
# 20000 ep | seed 1 | epoch 17700/20000 | train=0.007855 | validation=0.032263 | best=10419
# 20000 ep | seed 1 | epoch 17800/20000 | train=0.008049 | validation=0.032320 | best=10419
# 20000 ep | seed 1 | epoch 17900/20000 | train=0.007530 | validation=0.032864 | best=10419
# 20000 ep | seed 1 | epoch 18000/20000 | train=0.007825 | validation=0.032412 | best=10419
# 20000 ep | seed 1 | epoch 18100/20000 | train=0.007928 | validation=0.032563 | best=10419
# 20000 ep | seed 1 | epoch 18200/20000 | train=0.007718 | validation=0.032490 | best=10419
# 20000 ep | seed 1 | epoch 18300/20000 | train=0.007975 | validation=0.032380 | best=10419
# 20000 ep | seed 1 | epoch 18400/20000 | train=0.007710 | validation=0.032335 | best=10419
# 20000 ep | seed 1 | epoch 18500/20000 | train=0.007844 | validation=0.032398 | best=10419
# 20000 ep | seed 1 | epoch 18600/20000 | train=0.007900 | validation=0.032279 | best=10419
# 20000 ep | seed 1 | epoch 18700/20000 | train=0.007834 | validation=0.032453 | best=10419
# 20000 ep | seed 1 | epoch 18800/20000 | train=0.007890 | validation=0.032680 | best=10419
# 20000 ep | seed 1 | epoch 18900/20000 | train=0.007980 | validation=0.032462 | best=10419
# 20000 ep | seed 1 | epoch 19000/20000 | train=0.007583 | validation=0.032482 | best=10419
# 20000 ep | seed 1 | epoch 19100/20000 | train=0.007924 | validation=0.032523 | best=10419
# 20000 ep | seed 1 | epoch 19200/20000 | train=0.007651 | validation=0.032368 | best=10419
# 20000 ep | seed 1 | epoch 19300/20000 | train=0.007692 | validation=0.032362 | best=10419
# 20000 ep | seed 1 | epoch 19400/20000 | train=0.007860 | validation=0.032389 | best=10419
# 20000 ep | seed 1 | epoch 19500/20000 | train=0.007725 | validation=0.032322 | best=10419
# 20000 ep | seed 1 | epoch 19600/20000 | train=0.007767 | validation=0.032372 | best=10419
# 20000 ep | seed 1 | epoch 19700/20000 | train=0.007785 | validation=0.032350 | best=10419
# 20000 ep | seed 1 | epoch 19800/20000 | train=0.007763 | validation=0.032330 | best=10419
# 20000 ep | seed 1 | epoch 19900/20000 | train=0.007816 | validation=0.032343 | best=10419
# 20000 ep | seed 1 | epoch 20000/20000 | train=0.007946 | validation=0.032344 | best=10419
# [done] 20000 epochs, seed 1: selected epoch 10419, validation MSE=0.029982
#
# ================================================================================
# Budget 20000, seed 2
# ================================================================================
# [new run] 20000 epochs, seed 2
# 20000 ep | seed 2 | epoch     1/20000 | train=0.615377 | validation=0.532389 | best=1
# 20000 ep | seed 2 | epoch   100/20000 | train=0.067378 | validation=0.072957 | best=100
# 20000 ep | seed 2 | epoch   200/20000 | train=0.047615 | validation=0.058472 | best=198
# 20000 ep | seed 2 | epoch   300/20000 | train=0.038640 | validation=0.050382 | best=298
# 20000 ep | seed 2 | epoch   400/20000 | train=0.034459 | validation=0.045892 | best=389
# 20000 ep | seed 2 | epoch   500/20000 | train=0.030943 | validation=0.044311 | best=484
# 20000 ep | seed 2 | epoch   600/20000 | train=0.028915 | validation=0.042079 | best=597
# 20000 ep | seed 2 | epoch   700/20000 | train=0.026682 | validation=0.042403 | best=664
# 20000 ep | seed 2 | epoch   800/20000 | train=0.025548 | validation=0.039907 | best=768
# 20000 ep | seed 2 | epoch   900/20000 | train=0.023790 | validation=0.038314 | best=900
# 20000 ep | seed 2 | epoch  1000/20000 | train=0.023571 | validation=0.038092 | best=976
# 20000 ep | seed 2 | epoch  1100/20000 | train=0.022293 | validation=0.037163 | best=1092
# 20000 ep | seed 2 | epoch  1200/20000 | train=0.021761 | validation=0.036499 | best=1198
# 20000 ep | seed 2 | epoch  1300/20000 | train=0.021130 | validation=0.036774 | best=1280
# 20000 ep | seed 2 | epoch  1400/20000 | train=0.020821 | validation=0.036595 | best=1361
# 20000 ep | seed 2 | epoch  1500/20000 | train=0.020235 | validation=0.035323 | best=1418
# 20000 ep | seed 2 | epoch  1600/20000 | train=0.019796 | validation=0.036475 | best=1542
# 20000 ep | seed 2 | epoch  1700/20000 | train=0.019446 | validation=0.036213 | best=1675
# 20000 ep | seed 2 | epoch  1800/20000 | train=0.019481 | validation=0.036170 | best=1733
# 20000 ep | seed 2 | epoch  1900/20000 | train=0.018443 | validation=0.035794 | best=1819
# 20000 ep | seed 2 | epoch  2000/20000 | train=0.018336 | validation=0.036590 | best=1819
# 20000 ep | seed 2 | epoch  2100/20000 | train=0.018032 | validation=0.035231 | best=1819
# 20000 ep | seed 2 | epoch  2200/20000 | train=0.017680 | validation=0.035986 | best=2171
# 20000 ep | seed 2 | epoch  2300/20000 | train=0.017760 | validation=0.035594 | best=2171
# 20000 ep | seed 2 | epoch  2400/20000 | train=0.017247 | validation=0.036153 | best=2171
# 20000 ep | seed 2 | epoch  2500/20000 | train=0.017069 | validation=0.036627 | best=2433
# 20000 ep | seed 2 | epoch  2600/20000 | train=0.016758 | validation=0.035712 | best=2546
# 20000 ep | seed 2 | epoch  2700/20000 | train=0.016085 | validation=0.034593 | best=2697
# 20000 ep | seed 2 | epoch  2800/20000 | train=0.016109 | validation=0.036014 | best=2697
# 20000 ep | seed 2 | epoch  2900/20000 | train=0.016057 | validation=0.035448 | best=2697
# 20000 ep | seed 2 | epoch  3000/20000 | train=0.015952 | validation=0.035579 | best=2697
# 20000 ep | seed 2 | epoch  3100/20000 | train=0.016029 | validation=0.034786 | best=2697
# 20000 ep | seed 2 | epoch  3200/20000 | train=0.016195 | validation=0.034091 | best=3193
# 20000 ep | seed 2 | epoch  3300/20000 | train=0.015873 | validation=0.034256 | best=3231
# 20000 ep | seed 2 | epoch  3400/20000 | train=0.015290 | validation=0.035097 | best=3231
# 20000 ep | seed 2 | epoch  3500/20000 | train=0.014928 | validation=0.033545 | best=3458
# 20000 ep | seed 2 | epoch  3600/20000 | train=0.015303 | validation=0.035343 | best=3458
# 20000 ep | seed 2 | epoch  3700/20000 | train=0.014608 | validation=0.033445 | best=3458
# 20000 ep | seed 2 | epoch  3800/20000 | train=0.014441 | validation=0.033977 | best=3797
# 20000 ep | seed 2 | epoch  3900/20000 | train=0.015065 | validation=0.034941 | best=3797
# 20000 ep | seed 2 | epoch  4000/20000 | train=0.014479 | validation=0.034132 | best=3797
# 20000 ep | seed 2 | epoch  4100/20000 | train=0.014649 | validation=0.034170 | best=3797
# 20000 ep | seed 2 | epoch  4200/20000 | train=0.013789 | validation=0.036609 | best=3797
# 20000 ep | seed 2 | epoch  4300/20000 | train=0.014508 | validation=0.034535 | best=3797
# 20000 ep | seed 2 | epoch  4400/20000 | train=0.013748 | validation=0.035368 | best=3797
# 20000 ep | seed 2 | epoch  4500/20000 | train=0.013364 | validation=0.034777 | best=3797
# 20000 ep | seed 2 | epoch  4600/20000 | train=0.014049 | validation=0.036988 | best=3797
# 20000 ep | seed 2 | epoch  4700/20000 | train=0.014263 | validation=0.036744 | best=3797
# 20000 ep | seed 2 | epoch  4800/20000 | train=0.013623 | validation=0.035456 | best=3797
# 20000 ep | seed 2 | epoch  4900/20000 | train=0.013392 | validation=0.034052 | best=3797
# 20000 ep | seed 2 | epoch  5000/20000 | train=0.013694 | validation=0.035738 | best=3797
# 20000 ep | seed 2 | epoch  5100/20000 | train=0.013474 | validation=0.034444 | best=3797
# 20000 ep | seed 2 | epoch  5200/20000 | train=0.013201 | validation=0.034718 | best=3797
# 20000 ep | seed 2 | epoch  5300/20000 | train=0.013427 | validation=0.034228 | best=5223
# 20000 ep | seed 2 | epoch  5400/20000 | train=0.013182 | validation=0.035167 | best=5223
# 20000 ep | seed 2 | epoch  5500/20000 | train=0.012971 | validation=0.035120 | best=5223
# 20000 ep | seed 2 | epoch  5600/20000 | train=0.013031 | validation=0.033429 | best=5223
# 20000 ep | seed 2 | epoch  5700/20000 | train=0.012665 | validation=0.034561 | best=5223
# 20000 ep | seed 2 | epoch  5800/20000 | train=0.013115 | validation=0.035126 | best=5223
# 20000 ep | seed 2 | epoch  5900/20000 | train=0.013227 | validation=0.035195 | best=5223
# 20000 ep | seed 2 | epoch  6000/20000 | train=0.012403 | validation=0.034554 | best=5223
# 20000 ep | seed 2 | epoch  6100/20000 | train=0.012149 | validation=0.033175 | best=5223
# 20000 ep | seed 2 | epoch  6200/20000 | train=0.012642 | validation=0.033895 | best=5223
# 20000 ep | seed 2 | epoch  6300/20000 | train=0.012426 | validation=0.033933 | best=5223
# 20000 ep | seed 2 | epoch  6400/20000 | train=0.012530 | validation=0.033279 | best=5223
# 20000 ep | seed 2 | epoch  6500/20000 | train=0.012289 | validation=0.033574 | best=5223
# 20000 ep | seed 2 | epoch  6600/20000 | train=0.012129 | validation=0.033220 | best=6553
# 20000 ep | seed 2 | epoch  6700/20000 | train=0.011517 | validation=0.033337 | best=6553
# 20000 ep | seed 2 | epoch  6800/20000 | train=0.012187 | validation=0.033121 | best=6553
# 20000 ep | seed 2 | epoch  6900/20000 | train=0.012040 | validation=0.034672 | best=6820
# 20000 ep | seed 2 | epoch  7000/20000 | train=0.011895 | validation=0.035047 | best=6820
# 20000 ep | seed 2 | epoch  7100/20000 | train=0.012108 | validation=0.033973 | best=6820
# 20000 ep | seed 2 | epoch  7200/20000 | train=0.011665 | validation=0.032942 | best=6820
# 20000 ep | seed 2 | epoch  7300/20000 | train=0.011993 | validation=0.033496 | best=6820
# 20000 ep | seed 2 | epoch  7400/20000 | train=0.012170 | validation=0.033572 | best=6820
# 20000 ep | seed 2 | epoch  7500/20000 | train=0.011863 | validation=0.033230 | best=6820
# 20000 ep | seed 2 | epoch  7600/20000 | train=0.012414 | validation=0.034383 | best=7524
# 20000 ep | seed 2 | epoch  7700/20000 | train=0.011583 | validation=0.033442 | best=7688
# 20000 ep | seed 2 | epoch  7800/20000 | train=0.011372 | validation=0.033281 | best=7688
# 20000 ep | seed 2 | epoch  7900/20000 | train=0.011472 | validation=0.034985 | best=7688
# 20000 ep | seed 2 | epoch  8000/20000 | train=0.011722 | validation=0.033393 | best=7688
# 20000 ep | seed 2 | epoch  8100/20000 | train=0.011330 | validation=0.034505 | best=7688
# 20000 ep | seed 2 | epoch  8200/20000 | train=0.011072 | validation=0.032881 | best=7688
# 20000 ep | seed 2 | epoch  8300/20000 | train=0.011278 | validation=0.034231 | best=7688
# 20000 ep | seed 2 | epoch  8400/20000 | train=0.011205 | validation=0.033474 | best=7688
# 20000 ep | seed 2 | epoch  8500/20000 | train=0.011183 | validation=0.034132 | best=7688
# 20000 ep | seed 2 | epoch  8600/20000 | train=0.010324 | validation=0.033404 | best=7688
# 20000 ep | seed 2 | epoch  8700/20000 | train=0.010889 | validation=0.033252 | best=7688
# 20000 ep | seed 2 | epoch  8800/20000 | train=0.011032 | validation=0.033547 | best=7688
# 20000 ep | seed 2 | epoch  8900/20000 | train=0.011239 | validation=0.032864 | best=7688
# 20000 ep | seed 2 | epoch  9000/20000 | train=0.010979 | validation=0.033744 | best=7688
# 20000 ep | seed 2 | epoch  9100/20000 | train=0.010890 | validation=0.033466 | best=7688
# 20000 ep | seed 2 | epoch  9200/20000 | train=0.010730 | validation=0.032798 | best=7688
# 20000 ep | seed 2 | epoch  9300/20000 | train=0.010822 | validation=0.034288 | best=7688
# 20000 ep | seed 2 | epoch  9400/20000 | train=0.010363 | validation=0.032727 | best=7688
# 20000 ep | seed 2 | epoch  9500/20000 | train=0.010293 | validation=0.033317 | best=7688
# 20000 ep | seed 2 | epoch  9600/20000 | train=0.010585 | validation=0.033007 | best=7688
# 20000 ep | seed 2 | epoch  9700/20000 | train=0.010651 | validation=0.033422 | best=7688
# 20000 ep | seed 2 | epoch  9800/20000 | train=0.010555 | validation=0.032877 | best=9771
# 20000 ep | seed 2 | epoch  9900/20000 | train=0.010444 | validation=0.033786 | best=9771
# 20000 ep | seed 2 | epoch 10000/20000 | train=0.009900 | validation=0.033173 | best=9771
# 20000 ep | seed 2 | epoch 10100/20000 | train=0.010658 | validation=0.033338 | best=9771
# 20000 ep | seed 2 | epoch 10200/20000 | train=0.010471 | validation=0.032535 | best=10154
# 20000 ep | seed 2 | epoch 10300/20000 | train=0.009964 | validation=0.033098 | best=10154
# 20000 ep | seed 2 | epoch 10400/20000 | train=0.010239 | validation=0.033268 | best=10154
# 20000 ep | seed 2 | epoch 10500/20000 | train=0.010267 | validation=0.033274 | best=10154
# 20000 ep | seed 2 | epoch 10600/20000 | train=0.010332 | validation=0.033112 | best=10565
# 20000 ep | seed 2 | epoch 10700/20000 | train=0.010122 | validation=0.033684 | best=10565
# 20000 ep | seed 2 | epoch 10800/20000 | train=0.010061 | validation=0.032843 | best=10565
# 20000 ep | seed 2 | epoch 10900/20000 | train=0.009732 | validation=0.032586 | best=10831
# 20000 ep | seed 2 | epoch 11000/20000 | train=0.010024 | validation=0.033478 | best=10831
# 20000 ep | seed 2 | epoch 11100/20000 | train=0.009806 | validation=0.033436 | best=10831
# 20000 ep | seed 2 | epoch 11200/20000 | train=0.009754 | validation=0.032117 | best=10831
# 20000 ep | seed 2 | epoch 11300/20000 | train=0.009733 | validation=0.032683 | best=10831
# 20000 ep | seed 2 | epoch 11400/20000 | train=0.009713 | validation=0.032600 | best=10831
# 20000 ep | seed 2 | epoch 11500/20000 | train=0.009525 | validation=0.031947 | best=10831
# 20000 ep | seed 2 | epoch 11600/20000 | train=0.009446 | validation=0.031857 | best=10831
# 20000 ep | seed 2 | epoch 11700/20000 | train=0.009353 | validation=0.032946 | best=10831
# 20000 ep | seed 2 | epoch 11800/20000 | train=0.009732 | validation=0.032925 | best=10831
# 20000 ep | seed 2 | epoch 11900/20000 | train=0.009494 | validation=0.032320 | best=10831
# 20000 ep | seed 2 | epoch 12000/20000 | train=0.009357 | validation=0.032648 | best=10831
# 20000 ep | seed 2 | epoch 12100/20000 | train=0.009228 | validation=0.032599 | best=10831
# 20000 ep | seed 2 | epoch 12200/20000 | train=0.009243 | validation=0.032223 | best=10831
# 20000 ep | seed 2 | epoch 12300/20000 | train=0.009273 | validation=0.032283 | best=12287
# 20000 ep | seed 2 | epoch 12400/20000 | train=0.009397 | validation=0.031747 | best=12287
# 20000 ep | seed 2 | epoch 12500/20000 | train=0.009347 | validation=0.032251 | best=12287
# 20000 ep | seed 2 | epoch 12600/20000 | train=0.009126 | validation=0.032378 | best=12287
# ...
# 20000 ep | seed 4 | epoch  2300/20000 | train=0.017915 | validation=0.036986 | best=2260
# 20000 ep | seed 4 | epoch  2400/20000 | train=0.017138 | validation=0.038700 | best=2324
# 20000 ep | seed 4 | epoch  2500/20000 | train=0.017214 | validation=0.037021 | best=2324
# 20000 ep | seed 4 | epoch  2600/20000 | train=0.016171 | validation=0.036929 | best=2541
# 20000 ep | seed 4 | epoch  2700/20000 | train=0.016237 | validation=0.035226 | best=2652
# 20000 ep | seed 4 | epoch  2800/20000 | train=0.016696 | validation=0.035973 | best=2652
# 20000 ep | seed 4 | epoch  2900/20000 | train=0.016994 | validation=0.035701 | best=2814
# 20000 ep | seed 4 | epoch  3000/20000 | train=0.015899 | validation=0.035776 | best=2814
# 20000 ep | seed 4 | epoch  3100/20000 | train=0.015851 | validation=0.036851 | best=3064
# 20000 ep | seed 4 | epoch  3200/20000 | train=0.015795 | validation=0.035144 | best=3064
# 20000 ep | seed 4 | epoch  3300/20000 | train=0.015342 | validation=0.034865 | best=3292
# 20000 ep | seed 4 | epoch  3400/20000 | train=0.015806 | validation=0.035791 | best=3292
# 20000 ep | seed 4 | epoch  3500/20000 | train=0.015132 | validation=0.035355 | best=3292
# 20000 ep | seed 4 | epoch  3600/20000 | train=0.015374 | validation=0.034007 | best=3555
# 20000 ep | seed 4 | epoch  3700/20000 | train=0.015186 | validation=0.035100 | best=3555
# 20000 ep | seed 4 | epoch  3800/20000 | train=0.014771 | validation=0.034950 | best=3736
# 20000 ep | seed 4 | epoch  3900/20000 | train=0.014723 | validation=0.036000 | best=3855
# 20000 ep | seed 4 | epoch  4000/20000 | train=0.014912 | validation=0.033108 | best=3855
# 20000 ep | seed 4 | epoch  4100/20000 | train=0.014446 | validation=0.034186 | best=4025
# 20000 ep | seed 4 | epoch  4200/20000 | train=0.014759 | validation=0.034811 | best=4025
# 20000 ep | seed 4 | epoch  4300/20000 | train=0.014307 | validation=0.034270 | best=4025
# 20000 ep | seed 4 | epoch  4400/20000 | train=0.014205 | validation=0.034248 | best=4025
# 20000 ep | seed 4 | epoch  4500/20000 | train=0.014279 | validation=0.034162 | best=4025
# 20000 ep | seed 4 | epoch  4600/20000 | train=0.014355 | validation=0.034139 | best=4025
# 20000 ep | seed 4 | epoch  4700/20000 | train=0.014431 | validation=0.032909 | best=4025
# 20000 ep | seed 4 | epoch  4800/20000 | train=0.013918 | validation=0.033541 | best=4025
# 20000 ep | seed 4 | epoch  4900/20000 | train=0.014115 | validation=0.033359 | best=4025
# 20000 ep | seed 4 | epoch  5000/20000 | train=0.013402 | validation=0.033784 | best=4901
# 20000 ep | seed 4 | epoch  5100/20000 | train=0.014107 | validation=0.033791 | best=5027
# 20000 ep | seed 4 | epoch  5200/20000 | train=0.013208 | validation=0.033963 | best=5027
# 20000 ep | seed 4 | epoch  5300/20000 | train=0.013205 | validation=0.034039 | best=5235
# 20000 ep | seed 4 | epoch  5400/20000 | train=0.013085 | validation=0.033161 | best=5235
# 20000 ep | seed 4 | epoch  5500/20000 | train=0.013239 | validation=0.032915 | best=5235
# 20000 ep | seed 4 | epoch  5600/20000 | train=0.013664 | validation=0.033016 | best=5235
# 20000 ep | seed 4 | epoch  5700/20000 | train=0.013046 | validation=0.032554 | best=5666
# 20000 ep | seed 4 | epoch  5800/20000 | train=0.013063 | validation=0.033507 | best=5666
# 20000 ep | seed 4 | epoch  5900/20000 | train=0.012826 | validation=0.033088 | best=5666
# 20000 ep | seed 4 | epoch  6000/20000 | train=0.012824 | validation=0.033749 | best=5666
# 20000 ep | seed 4 | epoch  6100/20000 | train=0.012634 | validation=0.034243 | best=5666
# 20000 ep | seed 4 | epoch  6200/20000 | train=0.012613 | validation=0.032609 | best=5666
# 20000 ep | seed 4 | epoch  6300/20000 | train=0.012564 | validation=0.033067 | best=5666
# 20000 ep | seed 4 | epoch  6400/20000 | train=0.012987 | validation=0.034272 | best=5666
# 20000 ep | seed 4 | epoch  6500/20000 | train=0.012416 | validation=0.032728 | best=5666
# 20000 ep | seed 4 | epoch  6600/20000 | train=0.012166 | validation=0.033469 | best=5666
# 20000 ep | seed 4 | epoch  6700/20000 | train=0.012663 | validation=0.033033 | best=5666
# 20000 ep | seed 4 | epoch  6800/20000 | train=0.012399 | validation=0.032540 | best=5666
# 20000 ep | seed 4 | epoch  6900/20000 | train=0.012527 | validation=0.033285 | best=5666
# 20000 ep | seed 4 | epoch  7000/20000 | train=0.012405 | validation=0.033442 | best=5666
# 20000 ep | seed 4 | epoch  7100/20000 | train=0.012344 | validation=0.035080 | best=5666
# 20000 ep | seed 4 | epoch  7200/20000 | train=0.012056 | validation=0.032068 | best=5666
# 20000 ep | seed 4 | epoch  7300/20000 | train=0.011777 | validation=0.033731 | best=5666
# 20000 ep | seed 4 | epoch  7400/20000 | train=0.011498 | validation=0.033197 | best=5666
# 20000 ep | seed 4 | epoch  7500/20000 | train=0.011962 | validation=0.032925 | best=5666
# 20000 ep | seed 4 | epoch  7600/20000 | train=0.012096 | validation=0.034064 | best=5666
# 20000 ep | seed 4 | epoch  7700/20000 | train=0.011278 | validation=0.033237 | best=5666
# 20000 ep | seed 4 | epoch  7800/20000 | train=0.011615 | validation=0.033376 | best=5666
# 20000 ep | seed 4 | epoch  7900/20000 | train=0.011338 | validation=0.033269 | best=5666
# 20000 ep | seed 4 | epoch  8000/20000 | train=0.011336 | validation=0.033098 | best=5666
# 20000 ep | seed 4 | epoch  8100/20000 | train=0.011385 | validation=0.033545 | best=5666
# 20000 ep | seed 4 | epoch  8200/20000 | train=0.011206 | validation=0.033739 | best=5666
# 20000 ep | seed 4 | epoch  8300/20000 | train=0.011024 | validation=0.034616 | best=5666
# 20000 ep | seed 4 | epoch  8400/20000 | train=0.011439 | validation=0.035972 | best=5666
# 20000 ep | seed 4 | epoch  8500/20000 | train=0.011398 | validation=0.032751 | best=5666
# 20000 ep | seed 4 | epoch  8600/20000 | train=0.010964 | validation=0.032770 | best=5666
# 20000 ep | seed 4 | epoch  8700/20000 | train=0.010966 | validation=0.034065 | best=5666
# 20000 ep | seed 4 | epoch  8800/20000 | train=0.010996 | validation=0.032355 | best=5666
# 20000 ep | seed 4 | epoch  8900/20000 | train=0.010995 | validation=0.034705 | best=5666
# 20000 ep | seed 4 | epoch  9000/20000 | train=0.011258 | validation=0.032020 | best=5666
# 20000 ep | seed 4 | epoch  9100/20000 | train=0.010893 | validation=0.032734 | best=5666
# 20000 ep | seed 4 | epoch  9200/20000 | train=0.011069 | validation=0.034366 | best=5666
# 20000 ep | seed 4 | epoch  9300/20000 | train=0.010400 | validation=0.034942 | best=5666
# 20000 ep | seed 4 | epoch  9400/20000 | train=0.010666 | validation=0.034735 | best=5666
# 20000 ep | seed 4 | epoch  9500/20000 | train=0.010625 | validation=0.033359 | best=5666
# 20000 ep | seed 4 | epoch  9600/20000 | train=0.010463 | validation=0.033569 | best=5666
# 20000 ep | seed 4 | epoch  9700/20000 | train=0.011083 | validation=0.033901 | best=5666
# 20000 ep | seed 4 | epoch  9800/20000 | train=0.010535 | validation=0.034250 | best=5666
# 20000 ep | seed 4 | epoch  9900/20000 | train=0.010201 | validation=0.033529 | best=5666
# 20000 ep | seed 4 | epoch 10000/20000 | train=0.010263 | validation=0.035227 | best=5666
# 20000 ep | seed 4 | epoch 10100/20000 | train=0.010448 | validation=0.035007 | best=5666
# 20000 ep | seed 4 | epoch 10200/20000 | train=0.009815 | validation=0.033362 | best=5666
# 20000 ep | seed 4 | epoch 10300/20000 | train=0.010311 | validation=0.033976 | best=5666
# 20000 ep | seed 4 | epoch 10400/20000 | train=0.010223 | validation=0.033735 | best=5666
# 20000 ep | seed 4 | epoch 10500/20000 | train=0.010085 | validation=0.034990 | best=5666
# 20000 ep | seed 4 | epoch 10600/20000 | train=0.010165 | validation=0.034968 | best=5666
# 20000 ep | seed 4 | epoch 10700/20000 | train=0.009857 | validation=0.034421 | best=5666
# 20000 ep | seed 4 | epoch 10800/20000 | train=0.009953 | validation=0.034974 | best=5666
# 20000 ep | seed 4 | epoch 10900/20000 | train=0.009634 | validation=0.034287 | best=5666
# 20000 ep | seed 4 | epoch 11000/20000 | train=0.009595 | validation=0.033641 | best=5666
# 20000 ep | seed 4 | epoch 11100/20000 | train=0.009856 | validation=0.035114 | best=5666
# 20000 ep | seed 4 | epoch 11200/20000 | train=0.009407 | validation=0.033347 | best=5666
# 20000 ep | seed 4 | epoch 11300/20000 | train=0.009551 | validation=0.034484 | best=5666
# 20000 ep | seed 4 | epoch 11400/20000 | train=0.009474 | validation=0.034629 | best=5666
# 20000 ep | seed 4 | epoch 11500/20000 | train=0.009814 | validation=0.034013 | best=5666
# 20000 ep | seed 4 | epoch 11600/20000 | train=0.009328 | validation=0.034229 | best=5666
# 20000 ep | seed 4 | epoch 11700/20000 | train=0.010107 | validation=0.033996 | best=5666
# 20000 ep | seed 4 | epoch 11800/20000 | train=0.009312 | validation=0.034414 | best=5666
# 20000 ep | seed 4 | epoch 11900/20000 | train=0.009251 | validation=0.034607 | best=5666
# 20000 ep | seed 4 | epoch 12000/20000 | train=0.009246 | validation=0.034751 | best=5666
# 20000 ep | seed 4 | epoch 12100/20000 | train=0.009490 | validation=0.034005 | best=5666
# 20000 ep | seed 4 | epoch 12200/20000 | train=0.009306 | validation=0.035052 | best=5666
# 20000 ep | seed 4 | epoch 12300/20000 | train=0.009193 | validation=0.033893 | best=5666
# 20000 ep | seed 4 | epoch 12400/20000 | train=0.008906 | validation=0.034691 | best=5666
# 20000 ep | seed 4 | epoch 12500/20000 | train=0.009116 | validation=0.034557 | best=5666
# 20000 ep | seed 4 | epoch 12600/20000 | train=0.009002 | validation=0.034628 | best=5666
# 20000 ep | seed 4 | epoch 12700/20000 | train=0.009367 | validation=0.034718 | best=5666
# 20000 ep | seed 4 | epoch 12800/20000 | train=0.009150 | validation=0.035347 | best=5666
# 20000 ep | seed 4 | epoch 12900/20000 | train=0.009236 | validation=0.035552 | best=5666
# 20000 ep | seed 4 | epoch 13000/20000 | train=0.009054 | validation=0.034925 | best=5666
# 20000 ep | seed 4 | epoch 13100/20000 | train=0.008827 | validation=0.033859 | best=5666
# 20000 ep | seed 4 | epoch 13200/20000 | train=0.009158 | validation=0.034662 | best=5666
# 20000 ep | seed 4 | epoch 13300/20000 | train=0.008991 | validation=0.034686 | best=5666
# 20000 ep | seed 4 | epoch 13400/20000 | train=0.008929 | validation=0.034888 | best=5666
# 20000 ep | seed 4 | epoch 13500/20000 | train=0.008875 | validation=0.034421 | best=5666
# 20000 ep | seed 4 | epoch 13600/20000 | train=0.008634 | validation=0.034240 | best=5666
# 20000 ep | seed 4 | epoch 13700/20000 | train=0.008954 | validation=0.034837 | best=5666
# 20000 ep | seed 4 | epoch 13800/20000 | train=0.008900 | validation=0.034565 | best=5666
# 20000 ep | seed 4 | epoch 13900/20000 | train=0.008798 | validation=0.034314 | best=5666
# 20000 ep | seed 4 | epoch 14000/20000 | train=0.008582 | validation=0.034292 | best=5666
# 20000 ep | seed 4 | epoch 14100/20000 | train=0.008827 | validation=0.034478 | best=5666
# 20000 ep | seed 4 | epoch 14200/20000 | train=0.008459 | validation=0.034743 | best=5666
# 20000 ep | seed 4 | epoch 14300/20000 | train=0.008515 | validation=0.034604 | best=5666
# 20000 ep | seed 4 | epoch 14400/20000 | train=0.008508 | validation=0.034670 | best=5666
# 20000 ep | seed 4 | epoch 14500/20000 | train=0.008584 | validation=0.034457 | best=5666
# 20000 ep | seed 4 | epoch 14600/20000 | train=0.008440 | validation=0.034571 | best=5666
# 20000 ep | seed 4 | epoch 14700/20000 | train=0.008186 | validation=0.034543 | best=5666
# 20000 ep | seed 4 | epoch 14800/20000 | train=0.008264 | validation=0.034277 | best=5666
# 20000 ep | seed 4 | epoch 14900/20000 | train=0.008063 | validation=0.034953 | best=5666
# 20000 ep | seed 4 | epoch 15000/20000 | train=0.008328 | validation=0.034696 | best=5666
# 20000 ep | seed 4 | epoch 15100/20000 | train=0.008588 | validation=0.034411 | best=5666
# 20000 ep | seed 4 | epoch 15200/20000 | train=0.008233 | validation=0.035242 | best=5666
# 20000 ep | seed 4 | epoch 15300/20000 | train=0.008046 | validation=0.034197 | best=5666
# 20000 ep | seed 4 | epoch 15400/20000 | train=0.008278 | validation=0.034583 | best=5666
# 20000 ep | seed 4 | epoch 15500/20000 | train=0.008321 | validation=0.034631 | best=5666
# 20000 ep | seed 4 | epoch 15600/20000 | train=0.008083 | validation=0.034468 | best=5666
# 20000 ep | seed 4 | epoch 15700/20000 | train=0.008316 | validation=0.034728 | best=5666
# 20000 ep | seed 4 | epoch 15800/20000 | train=0.008321 | validation=0.033857 | best=5666
# 20000 ep | seed 4 | epoch 15900/20000 | train=0.008143 | validation=0.034404 | best=5666
# 20000 ep | seed 4 | epoch 16000/20000 | train=0.007966 | validation=0.034533 | best=5666
# 20000 ep | seed 4 | epoch 16100/20000 | train=0.008143 | validation=0.035133 | best=5666
# 20000 ep | seed 4 | epoch 16200/20000 | train=0.008154 | validation=0.034232 | best=5666
# 20000 ep | seed 4 | epoch 16300/20000 | train=0.007920 | validation=0.034258 | best=5666
# 20000 ep | seed 4 | epoch 16400/20000 | train=0.007898 | validation=0.034478 | best=5666
# 20000 ep | seed 4 | epoch 16500/20000 | train=0.007849 | validation=0.034392 | best=5666
# 20000 ep | seed 4 | epoch 16600/20000 | train=0.007799 | validation=0.034509 | best=5666
# 20000 ep | seed 4 | epoch 16700/20000 | train=0.007823 | validation=0.034260 | best=5666
# 20000 ep | seed 4 | epoch 16800/20000 | train=0.007657 | validation=0.034512 | best=5666
# 20000 ep | seed 4 | epoch 16900/20000 | train=0.007716 | validation=0.034619 | best=5666
# 20000 ep | seed 4 | epoch 17000/20000 | train=0.007993 | validation=0.034819 | best=5666
# 20000 ep | seed 4 | epoch 17100/20000 | train=0.007681 | validation=0.034413 | best=5666
# 20000 ep | seed 4 | epoch 17200/20000 | train=0.007746 | validation=0.034541 | best=5666
# 20000 ep | seed 4 | epoch 17300/20000 | train=0.007609 | validation=0.034604 | best=5666
# 20000 ep | seed 4 | epoch 17400/20000 | train=0.007841 | validation=0.034699 | best=5666
# 20000 ep | seed 4 | epoch 17500/20000 | train=0.007550 | validation=0.034536 | best=5666
# 20000 ep | seed 4 | epoch 17600/20000 | train=0.007937 | validation=0.034462 | best=5666
# 20000 ep | seed 4 | epoch 17700/20000 | train=0.007639 | validation=0.034273 | best=5666
# 20000 ep | seed 4 | epoch 17800/20000 | train=0.007382 | validation=0.034390 | best=5666
# 20000 ep | seed 4 | epoch 17900/20000 | train=0.007620 | validation=0.034518 | best=5666
# 20000 ep | seed 4 | epoch 18000/20000 | train=0.007423 | validation=0.034598 | best=5666
# 20000 ep | seed 4 | epoch 18100/20000 | train=0.007436 | validation=0.034701 | best=5666
# 20000 ep | seed 4 | epoch 18200/20000 | train=0.007675 | validation=0.034438 | best=5666
# 20000 ep | seed 4 | epoch 18300/20000 | train=0.007704 | validation=0.034474 | best=5666
# 20000 ep | seed 4 | epoch 18400/20000 | train=0.007643 | validation=0.034460 | best=5666
# 20000 ep | seed 4 | epoch 18500/20000 | train=0.007557 | validation=0.034569 | best=5666
# 20000 ep | seed 4 | epoch 18600/20000 | train=0.007740 | validation=0.034541 | best=5666
# 20000 ep | seed 4 | epoch 18700/20000 | train=0.007687 | validation=0.034531 | best=5666
# 20000 ep | seed 4 | epoch 18800/20000 | train=0.007575 | validation=0.034470 | best=5666
# 20000 ep | seed 4 | epoch 18900/20000 | train=0.007450 | validation=0.034535 | best=5666
# 20000 ep | seed 4 | epoch 19000/20000 | train=0.007622 | validation=0.034659 | best=5666
# 20000 ep | seed 4 | epoch 19100/20000 | train=0.007553 | validation=0.034481 | best=5666
# 20000 ep | seed 4 | epoch 19200/20000 | train=0.007653 | validation=0.034580 | best=5666
# 20000 ep | seed 4 | epoch 19300/20000 | train=0.007512 | validation=0.034474 | best=5666
# 20000 ep | seed 4 | epoch 19400/20000 | train=0.007666 | validation=0.034518 | best=5666
# 20000 ep | seed 4 | epoch 19500/20000 | train=0.007504 | validation=0.034538 | best=5666
# 20000 ep | seed 4 | epoch 19600/20000 | train=0.007662 | validation=0.034558 | best=5666
# 20000 ep | seed 4 | epoch 19700/20000 | train=0.007670 | validation=0.034533 | best=5666
# 20000 ep | seed 4 | epoch 19800/20000 | train=0.007551 | validation=0.034503 | best=5666
# 20000 ep | seed 4 | epoch 19900/20000 | train=0.007440 | validation=0.034508 | best=5666
# 20000 ep | seed 4 | epoch 20000/20000 | train=0.007521 | validation=0.034508 | best=5666
# [done] 20000 epochs, seed 4: selected epoch 5666, validation MSE=0.031039
#
# All requested runs are available.

# %% [markdown]
# ## Evaluation helpers

# %%
# %%sql

# %%
@torch.no_grad()
def generate_paths(model, split, num_steps=1000):
    parameter = next(model.parameters())
    conditions = torch.as_tensor(split["conditions"], dtype=parameter.dtype, device=parameter.device)
    actions = torch.as_tensor(split["starts"], dtype=parameter.dtype, device=parameter.device).clone()
    model.eval()
    paths = [actions.cpu().numpy().copy()]
    dt = 1.0 / num_steps
    def velocity(a, tau):
        t = torch.full((len(a), 1), tau, dtype=a.dtype, device=a.device)
        return model(torch.cat([a, t, conditions], dim=1))
    for step in range(num_steps):
        tau = step * dt
        k1 = velocity(actions, tau)
        k2 = velocity(actions + dt*k1/2, tau + dt/2)
        k3 = velocity(actions + dt*k2/2, tau + dt/2)
        k4 = velocity(actions + dt*k3, min(tau + dt, 1.0))
        actions = actions + dt/6 * (k1 + 2*k2 + 2*k3 + k4)
        if not torch.isfinite(actions).all():
            raise RuntimeError("Non-finite rollout")
        paths.append(actions.cpu().numpy().copy())
    return np.stack(paths, axis=1)


def target_distances(path, targets):
    p0, vectors = path[:-1], np.diff(path, axis=0)
    offsets = targets[:, None, :] - p0[None, :, :]
    denominator = np.maximum(np.sum(vectors**2, axis=1), 1e-30)
    fraction = np.clip(np.sum(offsets*vectors[None, :, :], axis=-1) / denominator[None, :], 0, 1)
    nearest = p0[None, :, :] + fraction[:, :, None]*vectors[None, :, :]
    return np.linalg.norm(targets[:, None, :] - nearest, axis=-1).min(axis=1)


def expert_at_tau(route, knots, tau):
    indices = np.clip(np.searchsorted(knots, tau, side="right") - 1, 0, 3)
    vectors = route[indices+1] - route[indices]
    intervals = knots[indices+1] - knots[indices]
    positions = route[indices] + ((tau-knots[indices])/intervals)[:, None]*vectors
    return positions, vectors/intervals[:, None]


@torch.no_grad()
def velocity_diagnostics(paths, split, model, num_probes=200):
    n, saved, _ = paths.shape
    indices = np.unique(np.linspace(0, saved-2, num_probes).round().astype(int))
    tau = (indices + 0.5) / (saved-1)
    roll = (paths[:, indices] + paths[:, indices+1])/2
    reference = [expert_at_tau(route, knots, tau) for route, knots in zip(split["routes"], split["knot_tau"])]
    expert_positions = np.stack([r[0] for r in reference])
    expert_derivatives = np.stack([r[1] for r in reference])
    parameter = next(model.parameters())
    def predict(actions):
        times = np.broadcast_to(tau[None, :, None], (n, len(tau), 1))
        conditions = np.broadcast_to(split["conditions"][:, None, :], (n, len(tau), 10))
        inputs = np.concatenate([actions, times, conditions], axis=-1).reshape(-1, 13)
        result = []
        for offset in range(0, len(inputs), 4096):
            x = torch.as_tensor(inputs[offset:offset+4096], dtype=parameter.dtype, device=parameter.device)
            result.append(model(x).cpu().numpy())
        return np.concatenate(result).reshape(n, len(tau), 2)
    def rms(x):
        return float(np.sqrt(np.mean(x*x)))
    rollout_reference = expert_derivatives - CONFIG["stabilizing_gain"]*(roll-expert_positions)
    return {"expert_rmse": rms(predict(expert_positions)-expert_derivatives),
            "rollout_rmse": rms(predict(roll)-rollout_reference),
            "expert_reference_rms": rms(expert_derivatives),
            "rollout_reference_rms": rms(rollout_reference)}

# %% [markdown]
# ## Evaluate every seed on the same fixed layouts
#
# The same 100 training layouts and the same 100 validation layouts are used for every budget and seed.
# The primary comparison is the validation-set **All four visited** rate at visit tolerance 0.02.

# %%
EVAL_STEPS = 1000
VISIT_TOLERANCE = 0.02

train_indices = np.random.default_rng(600).choice(
    len(splits["train"]["targets"]),
    size=100,
    replace=False,
)
validation_indices = np.arange(100)

eval_splits = {
    "Training": {
        k: v[train_indices].copy()
        for k, v in splits["train"].items()
    },
    "Validation": {
        k: v[validation_indices].copy()
        for k, v in splits["validation"].items()
    },
}

# Sanity check: the metric must recognize all exact expert paths.
for split in eval_splits.values():
    errors = np.stack([
        target_distances(route, targets)
        for route, targets in zip(
            split["routes"],
            split["targets"],
        )
    ])
    np.testing.assert_allclose(
        errors,
        0,
        atol=1e-12,
        rtol=0,
    )

seed_results = {}

for budget in BUDGETS:
    for seed in SEEDS:
        checkpoint = run_records[(budget, seed)]["checkpoint"]
        run_dir = run_records[(budget, seed)]["run_dir"]

        evaluation_model = CanonicalConditionalVelocityMLP().to(
            device=DEVICE,
            dtype=torch.float64,
        )
        evaluation_model.load_state_dict(
            checkpoint["model"],
            strict=True,
        )
        evaluation_model.eval()

        seed_results[(budget, seed)] = {}

        for split_name, split in eval_splits.items():
            print(
                f"Evaluating {budget} epochs, "
                f"seed {seed}: {split_name}..."
            )

            paths = generate_paths(
                evaluation_model,
                split,
                EVAL_STEPS,
            )

            distances = np.stack([
                target_distances(path, targets)
                for path, targets in zip(
                    paths,
                    split["targets"],
                )
            ])

            counts = (
                distances <= VISIT_TOLERANCE
            ).sum(axis=1)

            summary = {
                "all_visited_rate": float(
                    np.mean(counts == 4)
                ),
                "mean_visited": float(
                    counts.mean()
                ),
                "mean_worst_distance": float(
                    distances.max(axis=1).mean()
                ),
                "visit_count_histogram": np.bincount(
                    counts,
                    minlength=5,
                ).tolist(),
                **velocity_diagnostics(
                    paths,
                    split,
                    evaluation_model,
                ),
            }

            seed_results[(budget, seed)][split_name] = summary

            np.savez_compressed(
                Path(run_dir)
                / f"{split_name.lower()}_evaluation_rollouts.npz",
                paths=paths,
                starts=split["starts"],
                targets=split["targets"],
                target_distances=distances,
                visited_counts=counts,
                expert_lengths=split["lengths"],
            )

        del evaluation_model
        if DEVICE.type == "cuda":
            torch.cuda.empty_cache()

print("Evaluation complete.")
# Out:
# Evaluating 20000 epochs, seed 0: Training...
# Evaluating 20000 epochs, seed 0: Validation...
# Evaluating 20000 epochs, seed 1: Training...
# Evaluating 20000 epochs, seed 1: Validation...
# Evaluating 20000 epochs, seed 2: Training...
# Evaluating 20000 epochs, seed 2: Validation...
# Evaluating 20000 epochs, seed 3: Training...
# Evaluating 20000 epochs, seed 3: Validation...
# Evaluating 20000 epochs, seed 4: Training...
# Evaluating 20000 epochs, seed 4: Validation...
# Evaluation complete.

# %% [markdown]
# ## Per-seed results and mean ± standard deviation

# %%
# Per-seed validation table.
lines = [
    "| Budget | Seed | Selected epoch | Validation MSE | All four visited | Mean visited | Worst-target distance | Expert RMSE | Rollout RMSE |",
    "|---:|---:|---:|---:|---:|---:|---:|---:|---:|",
]

for budget in BUDGETS:
    for seed in SEEDS:
        checkpoint = run_records[(budget, seed)]["checkpoint"]
        r = seed_results[(budget, seed)]["Validation"]

        lines.append(
            f"| {budget} | {seed} | "
            f"{checkpoint['epoch']} | "
            f"{checkpoint['validation_loss']:.6f} | "
            f"{r['all_visited_rate']:.1%} | "
            f"{r['mean_visited']:.2f}/4 | "
            f"{r['mean_worst_distance']:.6f} | "
            f"{r['expert_rmse']:.6f} | "
            f"{r['rollout_rmse']:.6f} |"
        )

display(Markdown("\n".join(lines)))


def mean_std(values):
    values = np.asarray(values, dtype=float)
    return float(values.mean()), float(values.std(ddof=1))


aggregate = {}

for budget in BUDGETS:
    validation_rows = [
        seed_results[(budget, seed)]["Validation"]
        for seed in SEEDS
    ]

    success = [
        row["all_visited_rate"]
        for row in validation_rows
    ]
    mean_visited = [
        row["mean_visited"]
        for row in validation_rows
    ]
    worst_distance = [
        row["mean_worst_distance"]
        for row in validation_rows
    ]
    expert_rmse = [
        row["expert_rmse"]
        for row in validation_rows
    ]
    rollout_rmse = [
        row["rollout_rmse"]
        for row in validation_rows
    ]
    selected_epochs = [
        run_records[(budget, seed)]["checkpoint"]["epoch"]
        for seed in SEEDS
    ]

    aggregate[budget] = {
        "success": mean_std(success),
        "mean_visited": mean_std(mean_visited),
        "worst_distance": mean_std(worst_distance),
        "expert_rmse": mean_std(expert_rmse),
        "rollout_rmse": mean_std(rollout_rmse),
        "selected_epoch": mean_std(selected_epochs),
    }

summary_lines = [
    "| Budget | Validation success | Mean visited | Worst-target distance | Expert RMSE | Rollout RMSE |",
    "|---:|---:|---:|---:|---:|---:|",
]

for budget in BUDGETS:
    a = aggregate[budget]

    summary_lines.append(
        f"| {budget} | "
        f"{100*a['success'][0]:.2f}% ± {100*a['success'][1]:.2f} pp | "
        f"{a['mean_visited'][0]:.3f} ± {a['mean_visited'][1]:.3f} | "
        f"{a['worst_distance'][0]:.6f} ± {a['worst_distance'][1]:.6f} | "
        f"{a['expert_rmse'][0]:.6f} ± {a['expert_rmse'][1]:.6f} | "
        f"{a['rollout_rmse'][0]:.6f} ± {a['rollout_rmse'][1]:.6f} |"
    )

display(Markdown("### Across-seed summary\n\n" + "\n".join(summary_lines)))

for budget in BUDGETS:
    m, s = aggregate[budget]["selected_epoch"]
    print(
        f"{budget} epochs: selected epoch "
        f"{m:.1f} ± {s:.1f}"
    )


# Save machine-readable results.
serializable_seed_results = {
    f"{budget}_seed_{seed}": {
        "selected_epoch": int(
            run_records[(budget, seed)]["checkpoint"]["epoch"]
        ),
        "validation_loss": float(
            run_records[(budget, seed)]["checkpoint"]["validation_loss"]
        ),
        "Training": seed_results[(budget, seed)]["Training"],
        "Validation": seed_results[(budget, seed)]["Validation"],
    }
    for budget in BUDGETS
    for seed in SEEDS
}

serializable_aggregate = {
    str(budget): {
        metric: {
            "mean": float(values[0]),
            "std": float(values[1]),
        }
        for metric, values in aggregate[budget].items()
    }
    for budget in BUDGETS
}

summary_record = {
    "budgets": BUDGETS,
    "seeds": SEEDS,
    "visit_tolerance": VISIT_TOLERANCE,
    "ode_steps": EVAL_STEPS,
    "train_indices": train_indices.tolist(),
    "validation_indices": validation_indices.tolist(),
    "seed_results": serializable_seed_results,
    "aggregate": serializable_aggregate,
    "dataset_sha256": DATASET_SHA256,
    "note": (
        "Test split deliberately not used during seed sweep."
    ),
}

summary_path = SWEEP_ROOT / "seed_sweep_summary.json"
summary_path.write_text(
    json.dumps(summary_record, indent=2),
    encoding="utf-8",
)

print("\nSaved:", summary_path)
# Out:
# | Budget | Seed | Selected epoch | Validation MSE | All four visited | Mean visited | Worst-target distance | Expert RMSE | Rollout RMSE |
# |---:|---:|---:|---:|---:|---:|---:|---:|---:|
# | 20000 | 0 | 6550 | 0.029689 | 64.0% | 3.43/4 | 0.038084 | 0.153786 | 0.342374 |
# | 20000 | 1 | 10419 | 0.029982 | 66.0% | 3.47/4 | 0.035041 | 0.155462 | 0.287549 |
# | 20000 | 2 | 12287 | 0.030962 | 64.0% | 3.45/4 | 0.030960 | 0.138222 | 0.278159 |
# | 20000 | 3 | 2293 | 0.031303 | 49.0% | 3.07/4 | 0.049350 | 0.164343 | 0.395194 |
# | 20000 | 4 | 5666 | 0.031039 | 54.0% | 3.37/4 | 0.039902 | 0.149990 | 0.331481 |
# ### Across-seed summary
#
# | Budget | Validation success | Mean visited | Worst-target distance | Expert RMSE | Rollout RMSE |
# |---:|---:|---:|---:|---:|---:|
# | 20000 | 59.40% ± 7.47 pp | 3.358 ± 0.165 | 0.038668 ± 0.006865 | 0.152361 ± 0.009497 | 0.326951 ± 0.047034 |
# 20000 epochs: selected epoch 7443.0 ± 3962.3
#
# Saved: /home/u7779895/PycharmProjects/streaming-flow-policy/experiments/four_boxes_experiments/four_targets/runs/conditional_mlp_canonical_seed_sweep_20000/seed_sweep_summary.json

# %% [markdown]
# ## Visualize seed sensitivity

# %%
fig, ax = plt.subplots(
    figsize=(7, 4.5),
    dpi=140,
    constrained_layout=True,
)

x = np.arange(len(BUDGETS))

means = np.array([
    100 * aggregate[budget]["success"][0]
    for budget in BUDGETS
])
stds = np.array([
    100 * aggregate[budget]["success"][1]
    for budget in BUDGETS
])

ax.errorbar(
    x,
    means,
    yerr=stds,
    fmt="o",
    capsize=5,
    label="mean ± SD",
)

for i, budget in enumerate(BUDGETS):
    ys = [
        100
        * seed_results[(budget, seed)]["Validation"]["all_visited_rate"]
        for seed in SEEDS
    ]
    jitter = np.linspace(-0.06, 0.06, len(SEEDS))
    ax.scatter(
        np.full(len(SEEDS), x[i]) + jitter,
        ys,
        s=35,
        alpha=0.8,
        label="individual seeds" if i == 0 else None,
    )

ax.set_xticks(x)
ax.set_xticklabels([
    f"{budget} epochs"
    for budget in BUDGETS
])
ax.set_ylabel("Validation success (%)")
ax.set_title(
    "Seed sensitivity of four-target completion"
)
ax.grid(alpha=0.2)
ax.legend()

figure_path = SWEEP_ROOT / "seed_sensitivity_success.png"
fig.savefig(
    figure_path,
    dpi=180,
)
plt.show()

print("Saved:", figure_path)
# Out:
# Saved: /home/u7779895/PycharmProjects/streaming-flow-policy/experiments/four_boxes_experiments/four_targets/runs/conditional_mlp_canonical_seed_sweep/seed_sensitivity_success.png
