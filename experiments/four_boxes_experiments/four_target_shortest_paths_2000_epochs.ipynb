# %% [markdown]
# # Four-target shortest paths: sorted conditioning, 50 vs 2000 epochs
#
# **Question.** Does a longer training budget improve task completion for the coordinate-sorted conditional SFP model?
#
# - Load the existing 10,000 training and 1,000 validation layouts; do not load the test split.
# - Keep the four-layer, 128-unit SiLU MLP, sampling seeds, batch size and steps per epoch fixed.
# - Train from scratch for 2000 epochs with a 2000-epoch cosine schedule. This compares **budgets and associated schedules**, not an extra 1950 epochs of the old run.
# - Choose checkpoints using 20,000 fixed probes from independent validation layouts.
# - Compare the same 100 training and 100 validation layouts, starting exactly at the task start, with 1,000 RK4 steps and a 0.02 visit tolerance.
#
# **Interpretation.** Approximate target visits are the primary diagnostic. A shorter path that misses targets is not a better solution. No exact optimality claim is made from tolerance-based visits. The path parameter is normalized arc length, not physical time.
#
# **Usage:** Run top to bottom. Change `PROJECT_ROOT` if needed. Completed epochs resume automatically; a completed run skips training. No old notebook variables are required. Numerical training/evaluation must run on your machine with the saved dataset and 50-epoch checkpoint.

# %%
from pathlib import Path
import copy
import hashlib
import itertools
import json
import random
import sys
import platform
import numpy as np
import matplotlib.pyplot as plt
import torch
from torch import nn
from IPython.display import display, Markdown

PROJECT_ROOT = Path("/home/matcho/projects/streaming-flow-policy")
TASK_ROOT = PROJECT_ROOT / "experiments/four_boxes_experiments/four_targets"
DATASET_DIR = TASK_ROOT / "datasets/v1"
BASELINE_DIR = TASK_ROOT / "runs/conditional_mlp_canonical_v1_seed0"
RUN_DIR = TASK_ROOT / "runs/conditional_mlp_canonical_2000epochs_v1_seed0"
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

required = [DATASET_DIR / "config.json", DATASET_DIR / "train.npz",
            DATASET_DIR / "validation.npz", BASELINE_DIR / "best.pt",
            BASELINE_DIR / "config.json"]
missing = [str(p) for p in required if not p.exists()]
if missing:
    raise FileNotFoundError("Required existing files are missing:\n" + "\n".join(missing))

splits = {}
for name in ["train", "validation"]:
    with np.load(DATASET_DIR / f"{name}.npz", allow_pickle=False) as archive:
        splits[name] = {key: archive[key].copy() for key in archive.files}
    split = splits[name]
    n = len(split["targets"])
    for key, shape in {"starts": (n, 2), "targets": (n, 4, 2),
                       "conditions": (n, 10), "routes": (n, 5, 2),
                       "knot_tau": (n, 5), "lengths": (n,)}.items():
        assert split[key].shape == shape, (name, key, split[key].shape)
        assert np.isfinite(split[key]).all(), (name, key)
    assert np.all(np.diff(split["knot_tau"], axis=1) > 0)
    np.testing.assert_allclose(split["knot_tau"][:, 0], 0)
    np.testing.assert_allclose(split["knot_tau"][:, -1], 1)
    np.testing.assert_array_equal(split["conditions"], np.concatenate(
        [split["starts"], split["targets"].reshape(n, 8)], axis=1))
    np.testing.assert_array_equal(split["routes"][:, 0], split["starts"])
assert len(splits["train"]["targets"]) == 10_000
assert len(splits["validation"]["targets"]) == 1_000

def sha256(path):
    digest = hashlib.sha256()
    with path.open("rb") as stream:
        for block in iter(lambda: stream.read(1024 * 1024), b""):
            digest.update(block)
    return digest.hexdigest()

CONFIG = {
    "experiment": "full_dataset_canonical_budget_2000",
    "dataset_dir": str(DATASET_DIR),
    "input_preprocessing": "sort_targets_by_x_then_y",
    "num_training_layouts": 10_000,
    "training_seed": 0, "train_sampling_seed": 1000,
    "validation_probe_seed": 500, "validation_probe_size": 20_000,
    "num_epochs": 2000, "steps_per_epoch": 100, "batch_size": 2048,
    "learning_rate": 1e-3, "weight_decay": 1e-6,
    "hidden_dim": 128, "num_hidden_layers": 4,
    "sigma_0": 0.05, "stabilizing_gain": 2.5,
    "dataset_sha256": {p.name: sha256(p) for p in required[:3]},
}
BASELINE_CONFIG = json.loads((BASELINE_DIR / "config.json").read_text())
for key in ["input_preprocessing", "num_training_layouts", "training_seed",
            "train_sampling_seed", "validation_probe_seed", "validation_probe_size",
            "steps_per_epoch", "batch_size", "learning_rate", "weight_decay",
            "hidden_dim", "num_hidden_layers", "sigma_0", "stabilizing_gain"]:
    if BASELINE_CONFIG.get(key) != CONFIG[key]:
        raise ValueError(f"Baseline configuration mismatch: {key}")
assert BASELINE_CONFIG["num_epochs"] == 50

RUN_DIR.mkdir(parents=True, exist_ok=True)
config_path = RUN_DIR / "config.json"
if config_path.exists():
    if json.loads(config_path.read_text()) != CONFIG:
        raise ValueError("Run configuration changed. Use a new run directory.")
else:
    config_path.write_text(json.dumps(CONFIG, indent=2), encoding="utf-8")
print("Device:", DEVICE)
print("Layouts:", {k: len(v["targets"]) for k, v in splits.items()})
print("2000-epoch output:", RUN_DIR)
print("Test split has not been loaded.")
# Out:
# Device: cuda
# Layouts: {'train': 10000, 'validation': 1000}
# 2000-epoch output: /home/matcho/projects/streaming-flow-policy/experiments/four_boxes_experiments/four_targets/runs/conditional_mlp_canonical_2000epochs_v1_seed0
# Test split has not been loaded.

# %% [markdown]
# ## Reusable model and sampling definitions
# Coordinates remain in their original label order in the dataset. Sorting happens inside the model, before normalization. Expert order and optimal length are never network inputs.

# %%
def canonicalize_box_inputs(inputs):
    boxes = inputs[:, 5:].reshape(-1, 4, 2)
    for coordinate in [1, 0]:  # secondary y key, then primary x key
        order = torch.argsort(boxes[:, :, coordinate], dim=1, stable=True)
        boxes = torch.gather(boxes, 1, order.unsqueeze(-1).expand(-1, -1, 2))
    return torch.cat([inputs[:, :5], boxes.reshape(-1, 8)], dim=1)

class CanonicalConditionalVelocityMLP(nn.Module):
    def __init__(self):
        super().__init__()
        layers = []
        width = 13
        for _ in range(4):
            layers.extend([nn.Linear(width, 128), nn.SiLU()])
            width = 128
        layers.append(nn.Linear(width, 2))
        self.network = nn.Sequential(*layers)

    def forward(self, inputs):
        return self.network(2.0 * canonicalize_box_inputs(inputs) - 1.0)


def sample_batch(split, batch_size, rng):
    indices = rng.integers(0, len(split["targets"]), size=batch_size)
    tau = rng.uniform(0.0, 1.0, size=batch_size)
    routes = split["routes"][indices]
    knots = split["knot_tau"][indices]
    segments = np.clip((tau[:, None] >= knots[:, 1:]).sum(axis=1), 0, 3)
    rows = np.arange(batch_size)
    p0, p1 = routes[rows, segments], routes[rows, segments + 1]
    t0 = knots[rows, segments]
    interval = knots[rows, segments + 1] - t0
    positions = p0 + ((tau - t0) / interval)[:, None] * (p1 - p0)
    derivatives = (p1 - p0) / interval[:, None]
    offsets = (CONFIG["sigma_0"] * np.exp(-CONFIG["stabilizing_gain"] * tau))[:, None] * rng.standard_normal((batch_size, 2))
    actions = positions + offsets
    targets = derivatives - CONFIG["stabilizing_gain"] * offsets
    inputs = np.concatenate([actions, tau[:, None], split["conditions"][indices]], axis=1)
    return inputs.astype(np.float32), targets.astype(np.float32)


def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)


def atomic_save(payload, path):
    temporary = path.with_suffix(".tmp")
    torch.save(payload, temporary)
    temporary.replace(path)


@torch.no_grad()
def probe_mse(model, inputs, targets):
    model.eval()
    total = 0.0
    for offset in range(0, len(inputs), 4096):
        x, y = inputs[offset:offset+4096], targets[offset:offset+4096]
        loss = nn.functional.mse_loss(model(x), y)
        if not torch.isfinite(loss):
            raise RuntimeError("Non-finite validation loss")
        total += loss.item() * len(x)
    return total / len(inputs)

# %% [markdown]
# ## Train or resume the 2000-epoch run
# Each epoch has 100 batches of 2,048 freshly sampled points. Layouts are reused. Latest checkpoints include optimizer, schedule and random states; the best checkpoint is selected only by fixed validation MSE. GPU floating-point reproducibility may vary across runtime/hardware versions.

# %%
set_seed(CONFIG["training_seed"])
model_2000 = CanonicalConditionalVelocityMLP().to(device=DEVICE, dtype=torch.float32)
optimizer = torch.optim.AdamW(model_2000.parameters(), lr=CONFIG["learning_rate"],
                              weight_decay=CONFIG["weight_decay"])
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=CONFIG["num_epochs"])
train_rng = np.random.default_rng(CONFIG["train_sampling_seed"])
vx, vy = sample_batch(splits["validation"], CONFIG["validation_probe_size"],
                      np.random.default_rng(CONFIG["validation_probe_seed"]))
val_inputs = torch.from_numpy(vx).to(DEVICE)
val_targets = torch.from_numpy(vy).to(DEVICE)
history = {"train_loss": [], "validation_loss": []}
best_loss, best_epoch, start_epoch = float("inf"), None, 0
latest_path, best_path = RUN_DIR / "latest.pt", RUN_DIR / "best.pt"

if latest_path.exists():
    ckpt = torch.load(latest_path, map_location="cpu", weights_only=True)
    assert ckpt["config"] == CONFIG
    model_2000.load_state_dict(ckpt["model"])
    optimizer.load_state_dict(ckpt["optimizer"])
    scheduler.load_state_dict(ckpt["scheduler"])
    train_rng.bit_generator.state = ckpt["numpy_rng_state"]
    torch.set_rng_state(ckpt["torch_rng_state"])
    if DEVICE.type == "cuda" and ckpt["cuda_rng_states"]:
        torch.cuda.set_rng_state_all(ckpt["cuda_rng_states"])
    history = ckpt["history"]
    best_loss, best_epoch, start_epoch = ckpt["best_loss"], ckpt["best_epoch"], ckpt["epoch"]
    print(f"Resuming after epoch {start_epoch}")

for epoch in range(start_epoch + 1, CONFIG["num_epochs"] + 1):
    model_2000.train()
    loss_sum = 0.0
    for _ in range(CONFIG["steps_per_epoch"]):
        x, y = sample_batch(splits["train"], CONFIG["batch_size"], train_rng)
        x, y = torch.from_numpy(x).to(DEVICE), torch.from_numpy(y).to(DEVICE)
        optimizer.zero_grad(set_to_none=True)
        loss = nn.functional.mse_loss(model_2000(x), y)
        if not torch.isfinite(loss):
            raise RuntimeError("Non-finite training loss")
        loss.backward()
        optimizer.step()
        loss_sum += loss.item()
    train_loss = loss_sum / CONFIG["steps_per_epoch"]
    validation_loss = probe_mse(model_2000, val_inputs, val_targets)
    history["train_loss"].append(train_loss)
    history["validation_loss"].append(validation_loss)
    state = {name: tensor.detach().cpu().clone() for name, tensor in model_2000.state_dict().items()}
    if validation_loss < best_loss:
        best_loss, best_epoch = validation_loss, epoch
        atomic_save({"model": state, "epoch": epoch, "validation_loss": validation_loss,
                     "config": CONFIG}, best_path)
    scheduler.step()
    atomic_save({"model": state, "optimizer": optimizer.state_dict(),
                 "scheduler": scheduler.state_dict(), "epoch": epoch,
                 "history": copy.deepcopy(history), "best_loss": best_loss,
                 "best_epoch": best_epoch, "config": CONFIG,
                 "numpy_rng_state": train_rng.bit_generator.state,
                 "torch_rng_state": torch.get_rng_state(),
                 "cuda_rng_states": torch.cuda.get_rng_state_all() if DEVICE.type == "cuda" else []}, latest_path)
    if epoch == 1 or epoch % 5 == 0:
        print(f"Epoch {epoch:4d}/2000 | train={train_loss:.6f} | validation={validation_loss:.6f} | best epoch={best_epoch}")

best_2000 = torch.load(best_path, map_location="cpu", weights_only=True)
model_2000.load_state_dict(best_2000["model"])
model_2000.eval()
print(f"Selected epoch {best_2000['epoch']}, validation MSE={best_2000['validation_loss']:.6f}")
(RUN_DIR / "history.json").write_text(json.dumps(history, indent=2), encoding="utf-8")
# Out:
# Epoch    1/2000 | train=0.602732 | validation=0.514852 | best epoch=1
# Epoch    5/2000 | train=0.371632 | validation=0.354820 | best epoch=5
# Epoch   10/2000 | train=0.277493 | validation=0.268680 | best epoch=10
# Epoch   15/2000 | train=0.221631 | validation=0.215742 | best epoch=15
# Epoch   20/2000 | train=0.181894 | validation=0.178130 | best epoch=20
# Epoch   25/2000 | train=0.156910 | validation=0.153916 | best epoch=25
# Epoch   30/2000 | train=0.137472 | validation=0.137729 | best epoch=30
# Epoch   35/2000 | train=0.125253 | validation=0.125390 | best epoch=35
# Epoch   40/2000 | train=0.113532 | validation=0.113684 | best epoch=40
# Epoch   45/2000 | train=0.104257 | validation=0.105981 | best epoch=45
# Epoch   50/2000 | train=0.098147 | validation=0.100856 | best epoch=50
# Epoch   55/2000 | train=0.091394 | validation=0.094864 | best epoch=55
# Epoch   60/2000 | train=0.085569 | validation=0.090761 | best epoch=60
# Epoch   65/2000 | train=0.082525 | validation=0.086503 | best epoch=65
# Epoch   70/2000 | train=0.079262 | validation=0.083901 | best epoch=69
# Epoch   75/2000 | train=0.076763 | validation=0.080924 | best epoch=74
# Epoch   80/2000 | train=0.072268 | validation=0.079452 | best epoch=78
# Epoch   85/2000 | train=0.070033 | validation=0.076483 | best epoch=84
# Epoch   90/2000 | train=0.068867 | validation=0.074199 | best epoch=90
# Epoch   95/2000 | train=0.067521 | validation=0.074553 | best epoch=94
# Epoch  100/2000 | train=0.064639 | validation=0.072595 | best epoch=96
# Epoch  105/2000 | train=0.063842 | validation=0.069837 | best epoch=105
# Epoch  110/2000 | train=0.063137 | validation=0.068351 | best epoch=110
# Epoch  115/2000 | train=0.060876 | validation=0.066891 | best epoch=115
# Epoch  120/2000 | train=0.059732 | validation=0.066287 | best epoch=120
# Epoch  125/2000 | train=0.058598 | validation=0.066065 | best epoch=125
# Epoch  130/2000 | train=0.056953 | validation=0.064491 | best epoch=130
# Epoch  135/2000 | train=0.055541 | validation=0.064163 | best epoch=135
# Epoch  140/2000 | train=0.055584 | validation=0.062863 | best epoch=140
# Epoch  145/2000 | train=0.053975 | validation=0.063189 | best epoch=144
# Epoch  150/2000 | train=0.053088 | validation=0.061354 | best epoch=150
# Epoch  155/2000 | train=0.052305 | validation=0.061328 | best epoch=152
# Epoch  160/2000 | train=0.051652 | validation=0.061173 | best epoch=157
# Epoch  165/2000 | train=0.050953 | validation=0.061094 | best epoch=163
# Epoch  170/2000 | train=0.049836 | validation=0.059228 | best epoch=169
# Epoch  175/2000 | train=0.049606 | validation=0.058287 | best epoch=174
# Epoch  180/2000 | train=0.049422 | validation=0.058036 | best epoch=180
# Epoch  185/2000 | train=0.047712 | validation=0.059043 | best epoch=180
# Epoch  190/2000 | train=0.047321 | validation=0.056905 | best epoch=189
# Epoch  195/2000 | train=0.046434 | validation=0.056684 | best epoch=195
# Epoch  200/2000 | train=0.046314 | validation=0.057764 | best epoch=197
# Epoch  205/2000 | train=0.045769 | validation=0.055246 | best epoch=205
# Epoch  210/2000 | train=0.045192 | validation=0.054040 | best epoch=210
# Epoch  215/2000 | train=0.044907 | validation=0.056102 | best epoch=210
# Epoch  220/2000 | train=0.044726 | validation=0.053988 | best epoch=217
# Epoch  225/2000 | train=0.043659 | validation=0.054051 | best epoch=217
# Epoch  230/2000 | train=0.042932 | validation=0.053298 | best epoch=230
# Epoch  235/2000 | train=0.042596 | validation=0.053159 | best epoch=234
# Epoch  240/2000 | train=0.042260 | validation=0.053787 | best epoch=239
# Epoch  245/2000 | train=0.042926 | validation=0.052868 | best epoch=239
# Epoch  250/2000 | train=0.041899 | validation=0.052854 | best epoch=239
# Epoch  255/2000 | train=0.041709 | validation=0.051989 | best epoch=253
# Epoch  260/2000 | train=0.041325 | validation=0.052236 | best epoch=257
# Epoch  265/2000 | train=0.040497 | validation=0.051836 | best epoch=263
# Epoch  270/2000 | train=0.040209 | validation=0.052434 | best epoch=263
# Epoch  275/2000 | train=0.039972 | validation=0.050228 | best epoch=275
# Epoch  280/2000 | train=0.040036 | validation=0.050603 | best epoch=278
# Epoch  285/2000 | train=0.039797 | validation=0.051246 | best epoch=278
# Epoch  290/2000 | train=0.039057 | validation=0.050049 | best epoch=289
# Epoch  295/2000 | train=0.038843 | validation=0.052729 | best epoch=291
# Epoch  300/2000 | train=0.038614 | validation=0.049598 | best epoch=291
# Epoch  305/2000 | train=0.038124 | validation=0.049056 | best epoch=291
# Epoch  310/2000 | train=0.037628 | validation=0.049870 | best epoch=291
# Epoch  315/2000 | train=0.037912 | validation=0.047855 | best epoch=315
# Epoch  320/2000 | train=0.037504 | validation=0.049036 | best epoch=315
# Epoch  325/2000 | train=0.037350 | validation=0.047951 | best epoch=322
# Epoch  330/2000 | train=0.036559 | validation=0.047221 | best epoch=330
# Epoch  335/2000 | train=0.035682 | validation=0.048360 | best epoch=330
# Epoch  340/2000 | train=0.035780 | validation=0.047233 | best epoch=330
# Epoch  345/2000 | train=0.035879 | validation=0.046657 | best epoch=345
# Epoch  350/2000 | train=0.036350 | validation=0.048087 | best epoch=345
# Epoch  355/2000 | train=0.035159 | validation=0.048014 | best epoch=345
# Epoch  360/2000 | train=0.036526 | validation=0.045889 | best epoch=360
# Epoch  365/2000 | train=0.035333 | validation=0.047136 | best epoch=361
# Epoch  370/2000 | train=0.035161 | validation=0.047608 | best epoch=361
# Epoch  375/2000 | train=0.034933 | validation=0.046389 | best epoch=361
# Epoch  380/2000 | train=0.034564 | validation=0.046839 | best epoch=361
# Epoch  385/2000 | train=0.034677 | validation=0.046234 | best epoch=361
# Epoch  390/2000 | train=0.033950 | validation=0.046473 | best epoch=387
# Epoch  395/2000 | train=0.034389 | validation=0.046187 | best epoch=387
# Epoch  400/2000 | train=0.033855 | validation=0.046413 | best epoch=387
# Epoch  405/2000 | train=0.033681 | validation=0.046609 | best epoch=387
# Epoch  410/2000 | train=0.033725 | validation=0.045407 | best epoch=387
# Epoch  415/2000 | train=0.033246 | validation=0.046452 | best epoch=412
# Epoch  420/2000 | train=0.033503 | validation=0.046164 | best epoch=416
# Epoch  425/2000 | train=0.032889 | validation=0.044429 | best epoch=416
# Epoch  430/2000 | train=0.032414 | validation=0.045080 | best epoch=416
# Epoch  435/2000 | train=0.032610 | validation=0.048022 | best epoch=416
# Epoch  440/2000 | train=0.032621 | validation=0.045506 | best epoch=416
# Epoch  445/2000 | train=0.032477 | validation=0.046175 | best epoch=416
# Epoch  450/2000 | train=0.032825 | validation=0.045098 | best epoch=416
# Epoch  455/2000 | train=0.032534 | validation=0.045222 | best epoch=416
# Epoch  460/2000 | train=0.031817 | validation=0.044037 | best epoch=416
# Epoch  465/2000 | train=0.031654 | validation=0.044679 | best epoch=416
# Epoch  470/2000 | train=0.031658 | validation=0.044262 | best epoch=416
# Epoch  475/2000 | train=0.031419 | validation=0.044736 | best epoch=473
# Epoch  480/2000 | train=0.031453 | validation=0.044724 | best epoch=473
# Epoch  485/2000 | train=0.031365 | validation=0.043179 | best epoch=482
# Epoch  490/2000 | train=0.031271 | validation=0.044160 | best epoch=482
# Epoch  495/2000 | train=0.031299 | validation=0.043391 | best epoch=482
# Epoch  500/2000 | train=0.030924 | validation=0.044733 | best epoch=482
# Epoch  505/2000 | train=0.030301 | validation=0.043959 | best epoch=503
# Epoch  510/2000 | train=0.030417 | validation=0.042854 | best epoch=503
# Epoch  515/2000 | train=0.030753 | validation=0.042933 | best epoch=503
# Epoch  520/2000 | train=0.029911 | validation=0.044802 | best epoch=503
# Epoch  525/2000 | train=0.029913 | validation=0.042807 | best epoch=503
# Epoch  530/2000 | train=0.030148 | validation=0.043127 | best epoch=503
# Epoch  535/2000 | train=0.030113 | validation=0.043377 | best epoch=503
# Epoch  540/2000 | train=0.029878 | validation=0.042775 | best epoch=536
# Epoch  545/2000 | train=0.029835 | validation=0.042594 | best epoch=536
# Epoch  550/2000 | train=0.028998 | validation=0.042404 | best epoch=536
# Epoch  555/2000 | train=0.029992 | validation=0.042362 | best epoch=551
# Epoch  560/2000 | train=0.029735 | validation=0.042202 | best epoch=551
# Epoch  565/2000 | train=0.029889 | validation=0.042804 | best epoch=551
# Epoch  570/2000 | train=0.029196 | validation=0.042145 | best epoch=551
# Epoch  575/2000 | train=0.029047 | validation=0.042647 | best epoch=551
# Epoch  580/2000 | train=0.029106 | validation=0.042004 | best epoch=551
# Epoch  585/2000 | train=0.028411 | validation=0.042829 | best epoch=551
# Epoch  590/2000 | train=0.028722 | validation=0.042568 | best epoch=551
# Epoch  595/2000 | train=0.028835 | validation=0.042335 | best epoch=551
# Epoch  600/2000 | train=0.028704 | validation=0.042003 | best epoch=596
# Epoch  605/2000 | train=0.028251 | validation=0.043508 | best epoch=596
# Epoch  610/2000 | train=0.028319 | validation=0.042641 | best epoch=596
# Epoch  615/2000 | train=0.028373 | validation=0.042266 | best epoch=596
# Epoch  620/2000 | train=0.028414 | validation=0.040933 | best epoch=618
# Epoch  625/2000 | train=0.028345 | validation=0.042216 | best epoch=618
# Epoch  630/2000 | train=0.027819 | validation=0.042111 | best epoch=618
# Epoch  635/2000 | train=0.028385 | validation=0.043160 | best epoch=618
# Epoch  640/2000 | train=0.027793 | validation=0.041639 | best epoch=618
# Epoch  645/2000 | train=0.027784 | validation=0.042143 | best epoch=618
# Epoch  650/2000 | train=0.027641 | validation=0.042832 | best epoch=647
# Epoch  655/2000 | train=0.027838 | validation=0.041561 | best epoch=647
# Epoch  660/2000 | train=0.027776 | validation=0.040855 | best epoch=660
# Epoch  665/2000 | train=0.027760 | validation=0.041766 | best epoch=660
# Epoch  670/2000 | train=0.027122 | validation=0.042209 | best epoch=667
# Epoch  675/2000 | train=0.026941 | validation=0.041169 | best epoch=667
# Epoch  680/2000 | train=0.027226 | validation=0.040729 | best epoch=678
# Epoch  685/2000 | train=0.027222 | validation=0.042505 | best epoch=678
# Epoch  690/2000 | train=0.027250 | validation=0.041686 | best epoch=689
# Epoch  695/2000 | train=0.026202 | validation=0.041681 | best epoch=691
# Epoch  700/2000 | train=0.026979 | validation=0.041364 | best epoch=697
# Epoch  705/2000 | train=0.026899 | validation=0.040467 | best epoch=697
# Epoch  710/2000 | train=0.026387 | validation=0.041476 | best epoch=697
# Epoch  715/2000 | train=0.026888 | validation=0.041838 | best epoch=714
# Epoch  720/2000 | train=0.026755 | validation=0.041531 | best epoch=719
# Epoch  725/2000 | train=0.026321 | validation=0.040560 | best epoch=719
# Epoch  730/2000 | train=0.026610 | validation=0.041132 | best epoch=719
# Epoch  735/2000 | train=0.026652 | validation=0.040434 | best epoch=719
# Epoch  740/2000 | train=0.026352 | validation=0.040848 | best epoch=719
# Epoch  745/2000 | train=0.025962 | validation=0.040827 | best epoch=719
# Epoch  750/2000 | train=0.026491 | validation=0.040861 | best epoch=719
# Epoch  755/2000 | train=0.026045 | validation=0.039833 | best epoch=719
# Epoch  760/2000 | train=0.025794 | validation=0.040380 | best epoch=758
# Epoch  765/2000 | train=0.026576 | validation=0.040036 | best epoch=758
# Epoch  770/2000 | train=0.025462 | validation=0.040341 | best epoch=766
# Epoch  775/2000 | train=0.025559 | validation=0.040647 | best epoch=766
# Epoch  780/2000 | train=0.025875 | validation=0.039299 | best epoch=780
# Epoch  785/2000 | train=0.025866 | validation=0.040922 | best epoch=780
# Epoch  790/2000 | train=0.025385 | validation=0.040607 | best epoch=780
# Epoch  795/2000 | train=0.025592 | validation=0.040748 | best epoch=791
# Epoch  800/2000 | train=0.025144 | validation=0.040090 | best epoch=791
# Epoch  805/2000 | train=0.025332 | validation=0.039692 | best epoch=791
# Epoch  810/2000 | train=0.025432 | validation=0.039536 | best epoch=791
# Epoch  815/2000 | train=0.025271 | validation=0.039958 | best epoch=791
# Epoch  820/2000 | train=0.025096 | validation=0.040991 | best epoch=791
# Epoch  825/2000 | train=0.024701 | validation=0.039495 | best epoch=791
# Epoch  830/2000 | train=0.025369 | validation=0.038982 | best epoch=830
# Epoch  835/2000 | train=0.025475 | validation=0.039698 | best epoch=831
# Epoch  840/2000 | train=0.024730 | validation=0.039980 | best epoch=831
# Epoch  845/2000 | train=0.024936 | validation=0.041196 | best epoch=831
# Epoch  850/2000 | train=0.024362 | validation=0.040333 | best epoch=831
# Epoch  855/2000 | train=0.024545 | validation=0.039562 | best epoch=831
# Epoch  860/2000 | train=0.024270 | validation=0.040026 | best epoch=856
# Epoch  865/2000 | train=0.024434 | validation=0.039849 | best epoch=856
# Epoch  870/2000 | train=0.024596 | validation=0.038948 | best epoch=856
# Epoch  875/2000 | train=0.024473 | validation=0.040113 | best epoch=874
# Epoch  880/2000 | train=0.024574 | validation=0.039857 | best epoch=874
# Epoch  885/2000 | train=0.024394 | validation=0.038823 | best epoch=874
# Epoch  890/2000 | train=0.024909 | validation=0.039353 | best epoch=874
# Epoch  895/2000 | train=0.023979 | validation=0.039551 | best epoch=874
# Epoch  900/2000 | train=0.024577 | validation=0.038700 | best epoch=874
# Epoch  905/2000 | train=0.024283 | validation=0.038607 | best epoch=874
# Epoch  910/2000 | train=0.024257 | validation=0.039853 | best epoch=909
# Epoch  915/2000 | train=0.024018 | validation=0.038895 | best epoch=914
# Epoch  920/2000 | train=0.024037 | validation=0.039519 | best epoch=914
# Epoch  925/2000 | train=0.023927 | validation=0.039356 | best epoch=914
# Epoch  930/2000 | train=0.023946 | validation=0.039327 | best epoch=914
# Epoch  935/2000 | train=0.023588 | validation=0.038103 | best epoch=914
# Epoch  940/2000 | train=0.023752 | validation=0.039095 | best epoch=914
# Epoch  945/2000 | train=0.023387 | validation=0.037447 | best epoch=945
# Epoch  950/2000 | train=0.024215 | validation=0.038780 | best epoch=945
# Epoch  955/2000 | train=0.023927 | validation=0.039717 | best epoch=945
# Epoch  960/2000 | train=0.023297 | validation=0.039405 | best epoch=945
# Epoch  965/2000 | train=0.023094 | validation=0.038762 | best epoch=945
# Epoch  970/2000 | train=0.023651 | validation=0.038717 | best epoch=945
# Epoch  975/2000 | train=0.023862 | validation=0.037585 | best epoch=945
# Epoch  980/2000 | train=0.023436 | validation=0.038797 | best epoch=945
# Epoch  985/2000 | train=0.023084 | validation=0.038360 | best epoch=945
# Epoch  990/2000 | train=0.023257 | validation=0.038227 | best epoch=945
# Epoch  995/2000 | train=0.022888 | validation=0.038607 | best epoch=945
# Epoch 1000/2000 | train=0.023203 | validation=0.039712 | best epoch=945
# Epoch 1005/2000 | train=0.023350 | validation=0.038155 | best epoch=945
# Epoch 1010/2000 | train=0.022646 | validation=0.038550 | best epoch=945
# Epoch 1015/2000 | train=0.022985 | validation=0.038754 | best epoch=945
# Epoch 1020/2000 | train=0.022893 | validation=0.038265 | best epoch=945
# Epoch 1025/2000 | train=0.022731 | validation=0.038166 | best epoch=945
# Epoch 1030/2000 | train=0.023151 | validation=0.038732 | best epoch=945
# Epoch 1035/2000 | train=0.022728 | validation=0.037816 | best epoch=945
# Epoch 1040/2000 | train=0.023023 | validation=0.037815 | best epoch=945
# Epoch 1045/2000 | train=0.022503 | validation=0.039180 | best epoch=1044
# Epoch 1050/2000 | train=0.022757 | validation=0.038096 | best epoch=1044
# Epoch 1055/2000 | train=0.022876 | validation=0.038061 | best epoch=1044
# Epoch 1060/2000 | train=0.022710 | validation=0.038130 | best epoch=1044
# Epoch 1065/2000 | train=0.022918 | validation=0.037990 | best epoch=1044
# Epoch 1070/2000 | train=0.022064 | validation=0.038444 | best epoch=1044
# Epoch 1075/2000 | train=0.022648 | validation=0.038312 | best epoch=1044
# Epoch 1080/2000 | train=0.022194 | validation=0.038284 | best epoch=1044
# Epoch 1085/2000 | train=0.022436 | validation=0.038211 | best epoch=1081
# Epoch 1090/2000 | train=0.022698 | validation=0.038748 | best epoch=1081
# Epoch 1095/2000 | train=0.022248 | validation=0.038417 | best epoch=1081
# Epoch 1100/2000 | train=0.022820 | validation=0.037487 | best epoch=1081
# Epoch 1105/2000 | train=0.022270 | validation=0.037958 | best epoch=1081
# Epoch 1110/2000 | train=0.022516 | validation=0.038839 | best epoch=1081
# Epoch 1115/2000 | train=0.022100 | validation=0.037917 | best epoch=1081
# Epoch 1120/2000 | train=0.022179 | validation=0.037517 | best epoch=1081
# Epoch 1125/2000 | train=0.022134 | validation=0.038073 | best epoch=1122
# Epoch 1130/2000 | train=0.021841 | validation=0.038066 | best epoch=1126
# Epoch 1135/2000 | train=0.022045 | validation=0.038816 | best epoch=1126
# Epoch 1140/2000 | train=0.021562 | validation=0.037530 | best epoch=1126
# Epoch 1145/2000 | train=0.021539 | validation=0.036876 | best epoch=1126
# Epoch 1150/2000 | train=0.021385 | validation=0.037238 | best epoch=1126
# Epoch 1155/2000 | train=0.021413 | validation=0.037173 | best epoch=1126
# Epoch 1160/2000 | train=0.021572 | validation=0.037357 | best epoch=1126
# Epoch 1165/2000 | train=0.021337 | validation=0.037780 | best epoch=1126
# Epoch 1170/2000 | train=0.021716 | validation=0.037465 | best epoch=1126
# Epoch 1175/2000 | train=0.021789 | validation=0.037074 | best epoch=1126
# Epoch 1180/2000 | train=0.021763 | validation=0.037769 | best epoch=1126
# Epoch 1185/2000 | train=0.021014 | validation=0.037489 | best epoch=1126
# Epoch 1190/2000 | train=0.021610 | validation=0.037159 | best epoch=1126
# Epoch 1195/2000 | train=0.021733 | validation=0.036882 | best epoch=1126
# Epoch 1200/2000 | train=0.021875 | validation=0.037511 | best epoch=1126
# Epoch 1205/2000 | train=0.021569 | validation=0.036561 | best epoch=1126
# Epoch 1210/2000 | train=0.021136 | validation=0.037881 | best epoch=1126
# Epoch 1215/2000 | train=0.020929 | validation=0.036944 | best epoch=1126
# Epoch 1220/2000 | train=0.020892 | validation=0.036947 | best epoch=1126
# Epoch 1225/2000 | train=0.021329 | validation=0.037234 | best epoch=1126
# Epoch 1230/2000 | train=0.021331 | validation=0.037196 | best epoch=1126
# Epoch 1235/2000 | train=0.021048 | validation=0.038512 | best epoch=1126
# Epoch 1240/2000 | train=0.021357 | validation=0.036975 | best epoch=1126
# Epoch 1245/2000 | train=0.021609 | validation=0.037217 | best epoch=1126
# Epoch 1250/2000 | train=0.021095 | validation=0.036878 | best epoch=1126
# Epoch 1255/2000 | train=0.020930 | validation=0.036278 | best epoch=1251
# Epoch 1260/2000 | train=0.020724 | validation=0.036771 | best epoch=1251
# Epoch 1265/2000 | train=0.021068 | validation=0.037132 | best epoch=1251
# Epoch 1270/2000 | train=0.020927 | validation=0.037411 | best epoch=1251
# Epoch 1275/2000 | train=0.020809 | validation=0.036957 | best epoch=1251
# Epoch 1280/2000 | train=0.021024 | validation=0.037845 | best epoch=1251
# Epoch 1285/2000 | train=0.021215 | validation=0.036495 | best epoch=1251
# Epoch 1290/2000 | train=0.020843 | validation=0.037441 | best epoch=1286
# Epoch 1295/2000 | train=0.020628 | validation=0.036512 | best epoch=1286
# Epoch 1300/2000 | train=0.020878 | validation=0.036630 | best epoch=1286
# Epoch 1305/2000 | train=0.020876 | validation=0.037041 | best epoch=1286
# Epoch 1310/2000 | train=0.020690 | validation=0.036763 | best epoch=1286
# Epoch 1315/2000 | train=0.020323 | validation=0.035917 | best epoch=1315
# Epoch 1320/2000 | train=0.020681 | validation=0.036959 | best epoch=1315
# Epoch 1325/2000 | train=0.020835 | validation=0.037181 | best epoch=1315
# Epoch 1330/2000 | train=0.019903 | validation=0.037734 | best epoch=1315
# Epoch 1335/2000 | train=0.020401 | validation=0.037139 | best epoch=1315
# Epoch 1340/2000 | train=0.020506 | validation=0.036301 | best epoch=1315
# Epoch 1345/2000 | train=0.020447 | validation=0.037111 | best epoch=1315
# Epoch 1350/2000 | train=0.020780 | validation=0.036999 | best epoch=1315
# Epoch 1355/2000 | train=0.019920 | validation=0.037509 | best epoch=1352
# Epoch 1360/2000 | train=0.020322 | validation=0.036765 | best epoch=1352
# Epoch 1365/2000 | train=0.020544 | validation=0.036792 | best epoch=1352
# Epoch 1370/2000 | train=0.020266 | validation=0.037003 | best epoch=1352
# Epoch 1375/2000 | train=0.020119 | validation=0.036789 | best epoch=1352
# Epoch 1380/2000 | train=0.020081 | validation=0.036286 | best epoch=1352
# Epoch 1385/2000 | train=0.019808 | validation=0.036526 | best epoch=1352
# Epoch 1390/2000 | train=0.020317 | validation=0.036391 | best epoch=1352
# Epoch 1395/2000 | train=0.020356 | validation=0.036787 | best epoch=1352
# Epoch 1400/2000 | train=0.020283 | validation=0.036857 | best epoch=1352
# Epoch 1405/2000 | train=0.019861 | validation=0.035890 | best epoch=1352
# Epoch 1410/2000 | train=0.020323 | validation=0.036271 | best epoch=1352
# Epoch 1415/2000 | train=0.020182 | validation=0.036990 | best epoch=1352
# Epoch 1420/2000 | train=0.020121 | validation=0.036618 | best epoch=1417
# Epoch 1425/2000 | train=0.020154 | validation=0.036042 | best epoch=1422
# Epoch 1430/2000 | train=0.020132 | validation=0.036345 | best epoch=1422
# Epoch 1435/2000 | train=0.020026 | validation=0.036528 | best epoch=1422
# Epoch 1440/2000 | train=0.019722 | validation=0.036019 | best epoch=1422
# Epoch 1445/2000 | train=0.019941 | validation=0.036474 | best epoch=1422
# Epoch 1450/2000 | train=0.019723 | validation=0.036249 | best epoch=1422
# Epoch 1455/2000 | train=0.019808 | validation=0.036505 | best epoch=1422
# Epoch 1460/2000 | train=0.019844 | validation=0.036789 | best epoch=1422
# Epoch 1465/2000 | train=0.019448 | validation=0.036293 | best epoch=1422
# Epoch 1470/2000 | train=0.019663 | validation=0.036342 | best epoch=1422
# Epoch 1475/2000 | train=0.019364 | validation=0.036052 | best epoch=1422
# Epoch 1480/2000 | train=0.019542 | validation=0.036429 | best epoch=1422
# Epoch 1485/2000 | train=0.019810 | validation=0.036215 | best epoch=1422
# Epoch 1490/2000 | train=0.019432 | validation=0.036696 | best epoch=1422
# Epoch 1495/2000 | train=0.020073 | validation=0.036070 | best epoch=1422
# Epoch 1500/2000 | train=0.019060 | validation=0.035936 | best epoch=1496
# Epoch 1505/2000 | train=0.019481 | validation=0.036532 | best epoch=1496
# Epoch 1510/2000 | train=0.019512 | validation=0.036314 | best epoch=1496
# Epoch 1515/2000 | train=0.019838 | validation=0.036148 | best epoch=1496
# Epoch 1520/2000 | train=0.019221 | validation=0.036438 | best epoch=1496
# Epoch 1525/2000 | train=0.019311 | validation=0.036357 | best epoch=1496
# Epoch 1530/2000 | train=0.019385 | validation=0.036151 | best epoch=1496
# Epoch 1535/2000 | train=0.019394 | validation=0.036327 | best epoch=1496
# Epoch 1540/2000 | train=0.019605 | validation=0.035938 | best epoch=1496
# Epoch 1545/2000 | train=0.019520 | validation=0.036086 | best epoch=1496
# Epoch 1550/2000 | train=0.019525 | validation=0.035678 | best epoch=1496
# Epoch 1555/2000 | train=0.019312 | validation=0.035856 | best epoch=1496
# Epoch 1560/2000 | train=0.019322 | validation=0.035964 | best epoch=1496
# Epoch 1565/2000 | train=0.019143 | validation=0.036108 | best epoch=1496
# Epoch 1570/2000 | train=0.019601 | validation=0.036219 | best epoch=1496
# Epoch 1575/2000 | train=0.019137 | validation=0.036593 | best epoch=1496
# Epoch 1580/2000 | train=0.019154 | validation=0.036565 | best epoch=1496
# Epoch 1585/2000 | train=0.019394 | validation=0.036149 | best epoch=1496
# Epoch 1590/2000 | train=0.019218 | validation=0.036416 | best epoch=1496
# Epoch 1595/2000 | train=0.019177 | validation=0.035606 | best epoch=1594
# Epoch 1600/2000 | train=0.019289 | validation=0.036167 | best epoch=1594
# Epoch 1605/2000 | train=0.018835 | validation=0.035602 | best epoch=1594
# Epoch 1610/2000 | train=0.019281 | validation=0.035507 | best epoch=1594
# Epoch 1615/2000 | train=0.019101 | validation=0.036273 | best epoch=1594
# Epoch 1620/2000 | train=0.019003 | validation=0.035846 | best epoch=1594
# Epoch 1625/2000 | train=0.019009 | validation=0.035821 | best epoch=1594
# Epoch 1630/2000 | train=0.019251 | validation=0.035701 | best epoch=1594
# Epoch 1635/2000 | train=0.019217 | validation=0.035734 | best epoch=1594
# Epoch 1640/2000 | train=0.019402 | validation=0.035702 | best epoch=1594
# Epoch 1645/2000 | train=0.019085 | validation=0.036221 | best epoch=1594
# Epoch 1650/2000 | train=0.019175 | validation=0.035839 | best epoch=1594
# Epoch 1655/2000 | train=0.018870 | validation=0.035883 | best epoch=1594
# Epoch 1660/2000 | train=0.018654 | validation=0.035690 | best epoch=1594
# Epoch 1665/2000 | train=0.019051 | validation=0.036120 | best epoch=1594
# Epoch 1670/2000 | train=0.019048 | validation=0.035967 | best epoch=1594
# Epoch 1675/2000 | train=0.019091 | validation=0.036101 | best epoch=1594
# Epoch 1680/2000 | train=0.018872 | validation=0.035914 | best epoch=1594
# Epoch 1685/2000 | train=0.018896 | validation=0.035880 | best epoch=1594
# Epoch 1690/2000 | train=0.019074 | validation=0.035961 | best epoch=1594
# Epoch 1695/2000 | train=0.019112 | validation=0.035926 | best epoch=1594
# Epoch 1700/2000 | train=0.019055 | validation=0.035790 | best epoch=1594
# Epoch 1705/2000 | train=0.019015 | validation=0.035905 | best epoch=1594
# Epoch 1710/2000 | train=0.018635 | validation=0.035575 | best epoch=1709
# Epoch 1715/2000 | train=0.019433 | validation=0.035766 | best epoch=1709
# Epoch 1720/2000 | train=0.018865 | validation=0.035793 | best epoch=1709
# Epoch 1725/2000 | train=0.018952 | validation=0.035991 | best epoch=1709
# Epoch 1730/2000 | train=0.019016 | validation=0.035872 | best epoch=1709
# Epoch 1735/2000 | train=0.018774 | validation=0.035719 | best epoch=1709
# Epoch 1740/2000 | train=0.018965 | validation=0.035851 | best epoch=1709
# Epoch 1745/2000 | train=0.019367 | validation=0.035832 | best epoch=1709
# Epoch 1750/2000 | train=0.018772 | validation=0.036066 | best epoch=1709
# Epoch 1755/2000 | train=0.019022 | validation=0.035807 | best epoch=1709
# Epoch 1760/2000 | train=0.019180 | validation=0.035612 | best epoch=1709
# Epoch 1765/2000 | train=0.018620 | validation=0.036075 | best epoch=1709
# Epoch 1770/2000 | train=0.018976 | validation=0.035906 | best epoch=1709
# Epoch 1775/2000 | train=0.018338 | validation=0.035508 | best epoch=1709
# Epoch 1780/2000 | train=0.018570 | validation=0.035903 | best epoch=1709
# Epoch 1785/2000 | train=0.018531 | validation=0.035813 | best epoch=1709
# Epoch 1790/2000 | train=0.018660 | validation=0.035847 | best epoch=1709
# Epoch 1795/2000 | train=0.018755 | validation=0.035716 | best epoch=1709
# Epoch 1800/2000 | train=0.018719 | validation=0.035617 | best epoch=1709
# Epoch 1805/2000 | train=0.018949 | validation=0.035839 | best epoch=1709
# Epoch 1810/2000 | train=0.018821 | validation=0.036060 | best epoch=1709
# Epoch 1815/2000 | train=0.018815 | validation=0.035937 | best epoch=1709
# Epoch 1820/2000 | train=0.018905 | validation=0.035751 | best epoch=1709
# Epoch 1825/2000 | train=0.018783 | validation=0.035874 | best epoch=1709
# Epoch 1830/2000 | train=0.018803 | validation=0.035685 | best epoch=1709
# Epoch 1835/2000 | train=0.018544 | validation=0.035701 | best epoch=1709
# Epoch 1840/2000 | train=0.018748 | validation=0.035758 | best epoch=1709
# Epoch 1845/2000 | train=0.018612 | validation=0.035760 | best epoch=1709
# Epoch 1850/2000 | train=0.018861 | validation=0.035460 | best epoch=1709
# Epoch 1855/2000 | train=0.018279 | validation=0.035710 | best epoch=1709
# Epoch 1860/2000 | train=0.018967 | validation=0.035558 | best epoch=1709
# Epoch 1865/2000 | train=0.018714 | validation=0.035646 | best epoch=1709
# Epoch 1870/2000 | train=0.018568 | validation=0.035664 | best epoch=1709
# Epoch 1875/2000 | train=0.018556 | validation=0.035805 | best epoch=1709
# Epoch 1880/2000 | train=0.018791 | validation=0.035695 | best epoch=1709
# Epoch 1885/2000 | train=0.018739 | validation=0.035628 | best epoch=1709
# Epoch 1890/2000 | train=0.018627 | validation=0.035754 | best epoch=1709
# Epoch 1895/2000 | train=0.018811 | validation=0.035602 | best epoch=1709
# Epoch 1900/2000 | train=0.018676 | validation=0.035644 | best epoch=1709
# Epoch 1905/2000 | train=0.018757 | validation=0.035671 | best epoch=1709
# Epoch 1910/2000 | train=0.018553 | validation=0.035659 | best epoch=1709
# Epoch 1915/2000 | train=0.018752 | validation=0.035680 | best epoch=1709
# Epoch 1920/2000 | train=0.018783 | validation=0.035636 | best epoch=1709
# Epoch 1925/2000 | train=0.018775 | validation=0.035560 | best epoch=1709
# Epoch 1930/2000 | train=0.018676 | validation=0.035592 | best epoch=1709
# Epoch 1935/2000 | train=0.018539 | validation=0.035601 | best epoch=1709
# Epoch 1940/2000 | train=0.018563 | validation=0.035586 | best epoch=1709
# Epoch 1945/2000 | train=0.018352 | validation=0.035607 | best epoch=1709
# Epoch 1950/2000 | train=0.018514 | validation=0.035549 | best epoch=1709
# Epoch 1955/2000 | train=0.018601 | validation=0.035588 | best epoch=1709
# Epoch 1960/2000 | train=0.018755 | validation=0.035607 | best epoch=1709
# Epoch 1965/2000 | train=0.018892 | validation=0.035599 | best epoch=1709
# Epoch 1970/2000 | train=0.018646 | validation=0.035601 | best epoch=1709
# Epoch 1975/2000 | train=0.018446 | validation=0.035613 | best epoch=1709
# Epoch 1980/2000 | train=0.018530 | validation=0.035621 | best epoch=1709
# Epoch 1985/2000 | train=0.018473 | validation=0.035621 | best epoch=1709
# Epoch 1990/2000 | train=0.018650 | validation=0.035621 | best epoch=1709
# Epoch 1995/2000 | train=0.018413 | validation=0.035620 | best epoch=1709
# Epoch 2000/2000 | train=0.018357 | validation=0.035620 | best epoch=1709
# Selected epoch 1709, validation MSE=0.035412
# 101459

# %% [markdown]
# ## Evaluation helpers
# Visits use the minimum target-to-segment distance on the sampled rollout polyline. Expert-field error is a diagnostic using the stored expert, not a planning method. Probe locations and subset seeds reproduce the earlier comparison. Evaluation results are recomputed when run, avoiding stale caches.

# %%
@torch.no_grad()
def generate_paths(model, split, num_steps=1000):
    parameter = next(model.parameters())
    conditions = torch.as_tensor(split["conditions"], dtype=parameter.dtype, device=parameter.device)
    actions = torch.as_tensor(split["starts"], dtype=parameter.dtype, device=parameter.device).clone()
    model.eval()
    paths = [actions.cpu().numpy().copy()]
    dt = 1.0 / num_steps
    def velocity(a, tau):
        t = torch.full((len(a), 1), tau, dtype=a.dtype, device=a.device)
        return model(torch.cat([a, t, conditions], dim=1))
    for step in range(num_steps):
        tau = step * dt
        k1 = velocity(actions, tau)
        k2 = velocity(actions + dt*k1/2, tau + dt/2)
        k3 = velocity(actions + dt*k2/2, tau + dt/2)
        k4 = velocity(actions + dt*k3, min(tau + dt, 1.0))
        actions = actions + dt/6 * (k1 + 2*k2 + 2*k3 + k4)
        if not torch.isfinite(actions).all():
            raise RuntimeError("Non-finite rollout")
        paths.append(actions.cpu().numpy().copy())
    return np.stack(paths, axis=1)


def target_distances(path, targets):
    p0, vectors = path[:-1], np.diff(path, axis=0)
    offsets = targets[:, None, :] - p0[None, :, :]
    denominator = np.maximum(np.sum(vectors**2, axis=1), 1e-30)
    fraction = np.clip(np.sum(offsets*vectors[None, :, :], axis=-1) / denominator[None, :], 0, 1)
    nearest = p0[None, :, :] + fraction[:, :, None]*vectors[None, :, :]
    return np.linalg.norm(targets[:, None, :] - nearest, axis=-1).min(axis=1)


def expert_at_tau(route, knots, tau):
    indices = np.clip(np.searchsorted(knots, tau, side="right") - 1, 0, 3)
    vectors = route[indices+1] - route[indices]
    intervals = knots[indices+1] - knots[indices]
    positions = route[indices] + ((tau-knots[indices])/intervals)[:, None]*vectors
    return positions, vectors/intervals[:, None]


@torch.no_grad()
def velocity_diagnostics(paths, split, model, num_probes=200):
    n, saved, _ = paths.shape
    indices = np.unique(np.linspace(0, saved-2, num_probes).round().astype(int))
    tau = (indices + 0.5) / (saved-1)
    roll = (paths[:, indices] + paths[:, indices+1])/2
    reference = [expert_at_tau(route, knots, tau) for route, knots in zip(split["routes"], split["knot_tau"])]
    expert_positions = np.stack([r[0] for r in reference])
    expert_derivatives = np.stack([r[1] for r in reference])
    parameter = next(model.parameters())
    def predict(actions):
        times = np.broadcast_to(tau[None, :, None], (n, len(tau), 1))
        conditions = np.broadcast_to(split["conditions"][:, None, :], (n, len(tau), 10))
        inputs = np.concatenate([actions, times, conditions], axis=-1).reshape(-1, 13)
        result = []
        for offset in range(0, len(inputs), 4096):
            x = torch.as_tensor(inputs[offset:offset+4096], dtype=parameter.dtype, device=parameter.device)
            result.append(model(x).cpu().numpy())
        return np.concatenate(result).reshape(n, len(tau), 2)
    def rms(x):
        return float(np.sqrt(np.mean(x*x)))
    rollout_reference = expert_derivatives - CONFIG["stabilizing_gain"]*(roll-expert_positions)
    return {"expert_rmse": rms(predict(expert_positions)-expert_derivatives),
            "rollout_rmse": rms(predict(roll)-rollout_reference),
            "expert_reference_rms": rms(expert_derivatives),
            "rollout_reference_rms": rms(rollout_reference)}

# %% [markdown]
# ## Paired 50/2000-epoch evaluation
# Both checkpoints are coordinate-sorted models. The original unsorted model is not the 50-epoch comparator. Reported success rates are descriptive results for one seed, not confidence intervals.

# %%
EVAL_STEPS = 1000
VISIT_TOLERANCE = 0.02
train_indices = np.random.default_rng(600).choice(len(splits["train"]["targets"]), size=100, replace=False)
validation_indices = np.arange(100)
eval_splits = {
    "Training": {k: v[train_indices].copy() for k, v in splits["train"].items()},
    "Validation": {k: v[validation_indices].copy() for k, v in splits["validation"].items()},
}
# Verify the metric recognizes all expert routes.
for split in eval_splits.values():
    errors = np.stack([target_distances(r, t) for r, t in zip(split["routes"], split["targets"])])
    np.testing.assert_allclose(errors, 0, atol=1e-12, rtol=0)

checkpoints = {
    "50 epochs": torch.load(BASELINE_DIR / "best.pt", map_location="cpu", weights_only=True),
    "2000 epochs": best_2000,
}
results, rollout_arrays, distance_arrays = {}, {}, {}
for budget, checkpoint in checkpoints.items():
    evaluation_model = CanonicalConditionalVelocityMLP().to(device=DEVICE, dtype=torch.float64)
    evaluation_model.load_state_dict(checkpoint["model"], strict=True)
    evaluation_model.eval()
    results[budget] = {}
    for name, split in eval_splits.items():
        print(f"Evaluating {budget}: {name}...")
        paths = generate_paths(evaluation_model, split, EVAL_STEPS)
        distances = np.stack([target_distances(p, t) for p, t in zip(paths, split["targets"])])
        counts = (distances <= VISIT_TOLERANCE).sum(axis=1)
        lengths = np.linalg.norm(np.diff(paths, axis=1), axis=-1).sum(axis=1)
        summary = {"all_visited_rate": float(np.mean(counts == 4)),
                   "mean_visited": float(counts.mean()),
                   "mean_worst_distance": float(distances.max(axis=1).mean()),
                   "visit_count_histogram": np.bincount(counts, minlength=5).tolist(),
                   **velocity_diagnostics(paths, split, evaluation_model)}
        results[budget][name] = summary
        rollout_arrays[(budget, name)] = paths
        distance_arrays[(budget, name)] = distances
        np.savez_compressed(RUN_DIR / f"{budget.replace(' ', '_')}_{name}_rollouts.npz",
                            paths=paths, starts=split["starts"], targets=split["targets"],
                            target_distances=distances, visited_counts=counts,
                            generated_lengths=lengths, expert_lengths=split["lengths"])
    del evaluation_model

record = {"results": results, "selected_epochs": {k: int(v["epoch"]) for k, v in checkpoints.items()},
          "validation_losses": {k: float(v["validation_loss"]) for k, v in checkpoints.items()},
          "train_indices": train_indices.tolist(), "validation_indices": validation_indices.tolist(),
          "ode_steps": EVAL_STEPS, "visit_tolerance": VISIT_TOLERANCE,
          "initialization": "exact_start_without_noise", "dataset_sha256": CONFIG["dataset_sha256"],
          "checkpoint_sha256": {"50 epochs": sha256(BASELINE_DIR / "best.pt"), "2000 epochs": sha256(best_path)},
          "runtime": {"python": sys.version, "numpy": np.__version__, "torch": str(torch.__version__),
                      "device": str(DEVICE), "platform": platform.platform()}}
(RUN_DIR / "comparison.json").write_text(json.dumps(record, indent=2), encoding="utf-8")
print("Comparison saved.")
# Out:
# Evaluating 50 epochs: Training...
# Evaluating 50 epochs: Validation...
# Evaluating 2000 epochs: Training...
# Evaluating 2000 epochs: Validation...
# Comparison saved.

# %% [markdown]
# ## Results for discussion
# The six plotted layouts are validation indices 0–5, fixed in advance. The table uses all 100 evaluation layouts per split. Length ratios are not treated as optimality gaps; target visits remain approximate.

# %%
lines = ["| Budget | Layouts | All four visited | Mean visited | Worst-target distance | Expert RMSE | Rollout RMSE |",
         "|---|---|---:|---:|---:|---:|---:|"]
for budget, split_results in results.items():
    for name, r in split_results.items():
        lines.append(f"| {budget} | {name} | {r['all_visited_rate']:.1%} | {r['mean_visited']:.2f}/4 | {r['mean_worst_distance']:.6f} | {r['expert_rmse']:.6f} | {r['rollout_rmse']:.6f} |")
display(Markdown("\n".join(lines)))
for budget, checkpoint in checkpoints.items():
    print(f"{budget}: selected epoch {checkpoint['epoch']}, validation MSE={checkpoint['validation_loss']:.6f}")

fig, ax = plt.subplots(figsize=(8, 4), dpi=140, constrained_layout=True)
ax.plot(np.arange(1, len(history['validation_loss'])+1), history['validation_loss'],
        color='tab:blue', label='2000-epoch schedule: validation')
ax.plot(np.arange(1, len(history['train_loss'])+1), history['train_loss'],
        color='tab:blue', linestyle=':', alpha=0.6, label='2000-epoch schedule: training')
# The original sorted run stores loss history in latest.pt.
if (BASELINE_DIR / "latest.pt").exists():
    baseline_latest = torch.load(BASELINE_DIR / "latest.pt", map_location="cpu", weights_only=True)
    baseline_history = baseline_latest.get("history", {})
    if "validation_loss" in baseline_history:
        values = baseline_history["validation_loss"]
        ax.plot(np.arange(1, len(values)+1), values, color='tab:orange', label='50-epoch schedule: validation')
    del baseline_latest
ax.set(xlabel='Epoch', ylabel='MSE per derivative component', title='Separate training schedules, shared validation probes')
ax.set_yscale('log')
ax.grid(alpha=0.2)
ax.legend(fontsize=8)
fig.savefig(RUN_DIR / "loss_comparison.png", dpi=180)
plt.show()

fig, axes = plt.subplots(2, 3, figsize=(13, 8), dpi=140, constrained_layout=True)
subset = eval_splits['Validation']
for i, ax in enumerate(axes.flat):
    route, targets = subset['routes'][i], subset['targets'][i]
    ax.plot(route[:, 0], route[:, 1], '--', color='gray', label='Exact expert')
    labels = []
    for budget, color in [('50 epochs', 'tab:orange'), ('2000 epochs', 'tab:blue')]:
        path = rollout_arrays[(budget, 'Validation')][i]
        ax.plot(path[:, 0], path[:, 1], color=color, label=budget)
        ax.scatter(path[-1, 0], path[-1, 1], color=color, marker='x', s=30)
        count = np.sum(distance_arrays[(budget, 'Validation')][i] <= VISIT_TOLERANCE)
        labels.append(f"{budget.split()[0]} ep: {count}/4")
    ax.scatter(targets[:, 0], targets[:, 1], marker='s', color='gold', edgecolor='black', zorder=5)
    ax.scatter(route[0, 0], route[0, 1], marker='*', s=120, color='green', edgecolor='black', zorder=5)
    for j, target in enumerate(targets):
        ax.add_patch(plt.Circle(target, VISIT_TOLERANCE, fill=False, color='gray', alpha=0.5))
        ax.annotate(f'B{j+1}', target, xytext=(5, 5), textcoords='offset points', fontsize=8)
    ax.set_title(f"Validation index {i} | " + ', '.join(labels), fontsize=10)
    ax.set(xlabel='x', ylabel='y')
    ax.set_aspect('equal', adjustable='box')
    ax.grid(alpha=0.2)
axes[0, 0].legend(fontsize=8)
fig.savefig(RUN_DIR / "fixed_validation_paths.png", dpi=180)
plt.show()
# Out:
# | Budget | Layouts | All four visited | Mean visited | Worst-target distance | Expert RMSE | Rollout RMSE |
# |---|---|---:|---:|---:|---:|---:|
# | 50 epochs | Training | 3.0% | 1.22/4 | 0.139198 | 0.359818 | 0.636381 |
# | 50 epochs | Validation | 5.0% | 1.21/4 | 0.145750 | 0.364038 | 0.634431 |
# | 2000 epochs | Training | 59.0% | 3.40/4 | 0.035603 | 0.135947 | 0.304065 |
# | 2000 epochs | Validation | 58.0% | 3.30/4 | 0.047719 | 0.170343 | 0.365516 |
# 50 epochs: selected epoch 47, validation MSE=0.144602
# 2000 epochs: selected epoch 1709, validation MSE=0.035412

# %%
import itertools
import json
import numpy as np

VISIT_RADIUS = 0.02

# RUN_DIR must point to your 2000-epoch run.
rollout_file = RUN_DIR / "2000_epochs_Validation_rollouts.npz"
print("Reading:", rollout_file)

with np.load(rollout_file, allow_pickle=False) as saved:
    order_data = {
        key: saved[key].copy()
        for key in saved.files
    }


def target_contact_intervals(path, target, radius):
    """
    Intervals of normalized rollout parameter inside a target circle.
    Calculated on the saved piecewise-linear rollout.
    """
    starts = path[:-1]
    vectors = np.diff(path, axis=0)
    offsets = starts - target

    aa = np.sum(vectors * vectors, axis=1)
    bb = 2.0 * np.sum(offsets * vectors, axis=1)
    cc = np.sum(offsets * offsets, axis=1) - radius**2

    intervals = []
    num_segments = len(vectors)

    for index in range(num_segments):
        if aa[index] <= 1e-30:
            if cc[index] <= 0:
                lo, hi = 0.0, 1.0
            else:
                continue
        else:
            discriminant = bb[index]**2 - 4 * aa[index] * cc[index]

            if discriminant < 0:
                continue

            root = np.sqrt(discriminant)
            lo = max(0.0, (-bb[index] - root) / (2 * aa[index]))
            hi = min(1.0, (-bb[index] + root) / (2 * aa[index]))

            if lo > hi:
                continue

        entry = (index + lo) / num_segments
        exit_ = (index + hi) / num_segments

        # Merge continuous contact across adjacent saved segments.
        if intervals and entry <= intervals[-1][1] + 1e-10:
            intervals[-1][1] = max(intervals[-1][1], exit_)
        else:
            intervals.append([float(entry), float(exit_)])

    return intervals


permutations = np.array(
    list(itertools.permutations(range(4))),
    dtype=np.int64,
)

order_records = []

for layout_index, (path, start, targets) in enumerate(zip(
    order_data["paths"],
    order_data["starts"],
    order_data["targets"],
)):
    contacts = [
        target_contact_intervals(path, target, VISIT_RADIUS)
        for target in targets
    ]

    first_entries = np.array([
        intervals[0][0] if intervals else np.inf
        for intervals in contacts
    ])

    complete = bool(np.isfinite(first_entries).all())

    # Compare with the original target-to-polyline distance metric.
    expected_complete = bool(
        (order_data["target_distances"][layout_index]
         <= VISIT_RADIUS).all()
    )
    if complete != expected_complete:
        raise AssertionError(
            f"Contact/distance classification mismatch at "
            f"layout {layout_index}; inspect numerical boundary."
        )

    # Exact shortest open route through target centres.
    candidate_routes = np.concatenate([
        np.broadcast_to(start, (24, 1, 2)),
        targets[permutations],
    ], axis=1)

    candidate_lengths = np.linalg.norm(
        np.diff(candidate_routes, axis=1),
        axis=-1,
    ).sum(axis=1)

    optimal_length = float(candidate_lengths.min())

    if "expert_lengths" in order_data:
        np.testing.assert_allclose(
            optimal_length,
            order_data["expert_lengths"][layout_index],
            atol=1e-10,
            rtol=0,
        )

    record = {
        "evaluation_row": layout_index,
        "complete_at_radius": complete,
        "first_entries": [
            float(value) if np.isfinite(value) else None
            for value in first_entries
        ],
        "contact_episode_counts": [
            len(intervals) for intervals in contacts
        ],
        "has_reentry": any(len(intervals) > 1 for intervals in contacts),
        "optimal_length": optimal_length,
        "generated_length": float(
            np.linalg.norm(np.diff(path, axis=0), axis=1).sum()
        ),
        "order": None,
        "ambiguous_order": False,
        "order_length": None,
        "order_gap": None,
        "optimal_order": None,
    }

    if complete:
        order = np.argsort(first_entries, kind="stable")
        ambiguous = bool(
            np.any(np.diff(first_entries[order]) <= 1e-10)
        )
        record["ambiguous_order"] = ambiguous

        if not ambiguous:
            centre_route = np.vstack([start, targets[order]])
            order_length = float(
                np.linalg.norm(
                    np.diff(centre_route, axis=0), axis=1
                ).sum()
            )

            record["order"] = order.tolist()
            record["order_length"] = order_length
            record["order_gap"] = max(
                0.0, (order_length - optimal_length) / optimal_length
            )
            record["optimal_order"] = bool(np.isclose(
                order_length,
                optimal_length,
                atol=1e-10,
                rtol=1e-8,
            ))

    order_records.append(record)

print("Contact extraction and expert-length checks passed.")
# Out:
# Reading: /home/matcho/projects/streaming-flow-policy/experiments/four_boxes_experiments/four_targets/runs/conditional_mlp_canonical_2000epochs_v1_seed0/2000_epochs_Validation_rollouts.npz
# Contact extraction and expert-length checks passed.

# %%
complete_records = [
    r for r in order_records
    if r["complete_at_radius"]
]

valid_order_records = [
    r for r in complete_records
    if not r["ambiguous_order"]
]

optimal_order_records = [
    r for r in valid_order_records
    if r["optimal_order"]
]

print("Validation layouts:", len(order_records))
print(
    f"All four visited within radius {VISIT_RADIUS}:",
    len(complete_records),
)
print(
    "Complete paths with ambiguous first-entry order:",
    len(complete_records) - len(valid_order_records),
)
print(
    "Complete paths with unambiguous order:",
    len(valid_order_records),
)

if valid_order_records:
    gaps = np.array([
        r["order_gap"] for r in valid_order_records
    ])

    print(
        "\nOptimal first-visit order among complete, "
        "unambiguous paths:",
        f"{len(optimal_order_records)} / {len(valid_order_records)} "
        f"({len(optimal_order_records) / len(valid_order_records):.1%})",
    )
    print(
        "Complete + optimal first-visit order among ALL layouts:",
        f"{len(optimal_order_records)} / {len(order_records)}",
    )
    print(f"Median order-length gap: {np.median(gaps):.2%}")
    print(f"P90 order-length gap: {np.quantile(gaps, 0.90):.2%}")
    print(f"Maximum order-length gap: {gaps.max():.2%}")

    print(
        "Complete paths with target-circle re-entry:",
        sum(r["has_reentry"] for r in valid_order_records),
    )

    print("\nLargest order-length gaps among complete paths:")
    print(
        f"{'Row':>5} {'First-visit order':>20} "
        f"{'Order gap':>12} {'Re-entry':>10}"
    )

    for record in sorted(
        valid_order_records,
        key=lambda r: r["order_gap"],
        reverse=True,
    )[:10]:
        order_text = " -> ".join(
            str(index + 1) for index in record["order"]
        )
        print(
            f"{record['evaluation_row']:>5} "
            f"{order_text:>20} "
            f"{record['order_gap']:>11.2%} "
            f"{str(record['has_reentry']):>10}"
        )

output_file = RUN_DIR / "first_visit_order_diagnostics.json"

output_file.write_text(
    json.dumps({
        "source_rollouts": str(rollout_file),
        "visit_radius": VISIT_RADIUS,
        "order_definition": "first entry into each target circle",
        "records": order_records,
    }, indent=2),
    encoding="utf-8",
)

print("\nSaved:", output_file)
# Out:
# Validation layouts: 100
# All four visited within radius 0.02: 58
# Complete paths with ambiguous first-entry order: 0
# Complete paths with unambiguous order: 58
#
# Optimal first-visit order among complete, unambiguous paths: 58 / 58 (100.0%)
# Complete + optimal first-visit order among ALL layouts: 58 / 100
# Median order-length gap: 0.00%
# P90 order-length gap: 0.00%
# Maximum order-length gap: 0.00%
# Complete paths with target-circle re-entry: 0
#
# Largest order-length gaps among complete paths:
#   Row    First-visit order    Order gap   Re-entry
#     0     4 -> 2 -> 1 -> 3       0.00%      False
#     1     3 -> 1 -> 2 -> 4       0.00%      False
#     3     2 -> 1 -> 4 -> 3       0.00%      False
#     4     2 -> 4 -> 1 -> 3       0.00%      False
#     6     4 -> 2 -> 1 -> 3       0.00%      False
#     8     4 -> 2 -> 3 -> 1       0.00%      False
#    10     2 -> 3 -> 1 -> 4       0.00%      False
#    12     4 -> 1 -> 3 -> 2       0.00%      False
#    15     1 -> 3 -> 4 -> 2       0.00%      False
#    16     3 -> 4 -> 1 -> 2       0.00%      False
#
# Saved: /home/matcho/projects/streaming-flow-policy/experiments/four_boxes_experiments/four_targets/runs/conditional_mlp_canonical_2000epochs_v1_seed0/first_visit_order_diagnostics.json

# %%
from pathlib import Path
import numpy as np

dataset_dir = Path(
    "/home/matcho/projects/streaming-flow-policy"
    "/experiments/four_boxes_experiments/four_targets/datasets/v1"
)

def layout_key(targets):
    targets = np.round(targets, decimals=10)
    order = np.lexsort((targets[:, 1], targets[:, 0]))
    return tuple(targets[order].ravel())

keys = {}

for name in ["train", "validation"]:
    with np.load(
        dataset_dir / f"{name}.npz",
        allow_pickle=False,
    ) as saved:
        targets = saved["targets"]
        keys[name] = {layout_key(layout) for layout in targets}

        duplicates = len(targets) - len(keys[name])
        print(f"{name}: {len(targets)} layouts, {duplicates} duplicates")
        assert duplicates == 0

overlap = keys["train"] & keys["validation"]

print("Shared layouts between train and validation:", len(overlap))
assert len(overlap) == 0

print("Check passed: saved training and validation layouts do not overlap.")
# Out:
# train: 10000 layouts, 0 duplicates
# validation: 1000 layouts, 0 duplicates
# Shared layouts between train and validation: 0
# Check passed: saved training and validation layouts do not overlap.

# %%
# Load the untouched test split only for final evaluation.

with np.load(DATASET_DIR / "test.npz", allow_pickle=False) as archive:
    test_split = {
        key: archive[key].copy()
        for key in archive.files
    }

n_test = len(test_split["targets"])

print("Test layouts:", n_test)
print("Condition shape:", test_split["conditions"].shape)
# Out:
# Test layouts: 1000
# Condition shape: (1000, 10)

# %%
# Final test-set evaluation.
# Do not use these results to tune the model afterwards.

FINAL_VISIT_TOLERANCE = 0.02
FINAL_EVAL_STEPS = 1000

final_model = CanonicalConditionalVelocityMLP().to(
    device=DEVICE,
    dtype=torch.float64,
)

final_model.load_state_dict(
    best_2000["model"],
    strict=True,
)

final_model.eval()

print(
    f"Evaluating final model "
    f"(selected epoch {best_2000['epoch']}) "
    f"on {len(test_split['targets'])} unseen test layouts..."
)

test_paths = generate_paths(
    final_model,
    test_split,
    num_steps=FINAL_EVAL_STEPS,
)

test_distances = np.stack([
    target_distances(path, targets)
    for path, targets in zip(
        test_paths,
        test_split["targets"],
    )
])

test_visited_counts = (
    test_distances <= FINAL_VISIT_TOLERANCE
).sum(axis=1)

test_generated_lengths = np.linalg.norm(
    np.diff(test_paths, axis=1),
    axis=-1,
).sum(axis=1)

test_summary = {
    "all_visited_rate": float(
        np.mean(test_visited_counts == 4)
    ),
    "mean_visited": float(
        test_visited_counts.mean()
    ),
    "mean_worst_distance": float(
        test_distances.max(axis=1).mean()
    ),
    "visit_count_histogram": np.bincount(
        test_visited_counts,
        minlength=5,
    ).tolist(),
    **velocity_diagnostics(
        test_paths,
        test_split,
        final_model,
    ),
}

print("\nFinal test results")
print("------------------")
print(
    f"All four visited: "
    f"{test_summary['all_visited_rate']:.1%}"
)
print(
    f"Mean targets visited: "
    f"{test_summary['mean_visited']:.2f} / 4"
)
print(
    f"Mean worst-target distance: "
    f"{test_summary['mean_worst_distance']:.6f}"
)
print(
    "Counts for visiting 0/1/2/3/4 targets:",
    test_summary["visit_count_histogram"],
)
print(
    f"Expert-path velocity RMSE: "
    f"{test_summary['expert_rmse']:.6f}"
)
print(
    f"Rollout velocity RMSE: "
    f"{test_summary['rollout_rmse']:.6f}"
)
# Out:
# Evaluating final model (selected epoch 1709) on 1000 unseen test layouts...
#
# Final test results
# ------------------
# All four visited: 50.9%
# Mean targets visited: 3.19 / 4
# Mean worst-target distance: 0.048098
# Counts for visiting 0/1/2/3/4 targets: [14, 58, 156, 263, 509]
# Expert-path velocity RMSE: 0.180386
# Rollout velocity RMSE: 0.377351

# %%
# Path-length quality, only for completed tasks.

complete_mask = (test_visited_counts == 4)

num_complete = int(complete_mask.sum())

print(
    f"\nApproximately complete test paths: "
    f"{num_complete}/{len(test_visited_counts)}"
)

if num_complete > 0:
    length_ratios = (
        test_generated_lengths[complete_mask]
        / test_split["lengths"][complete_mask]
    )

    print(
        f"Mean learned / optimal length ratio: "
        f"{length_ratios.mean():.4f}"
    )
    print(
        f"Median learned / optimal length ratio: "
        f"{np.median(length_ratios):.4f}"
    )
    print(
        f"90th percentile ratio: "
        f"{np.percentile(length_ratios, 90):.4f}"
    )
else:
    print(
        "No complete test paths; "
        "shortest-path ratio is not meaningful yet."
    )
# Out:
# Approximately complete test paths: 509/1000
# Mean learned / optimal length ratio: 0.9992
# Median learned / optimal length ratio: 0.9982
# 90th percentile ratio: 1.0133

# %%
import numpy as np
import matplotlib.pyplot as plt

start = np.array([0.5, 0.08])

# Same four physical target positions
targets = np.array([
    [0.22, 0.30],
    [0.72, 0.28],
    [0.78, 0.72],
    [0.30, 0.78],
])

# Same physical route in both figures
route_order = [0, 1, 2, 3]

# Left: original labels
labels_left = ["B1", "B2", "B3", "B4"]

# Right: same target positions, but different labels
labels_right = ["B3", "B1", "B4", "B2"]

fig, axes = plt.subplots(1, 2, figsize=(10, 4.5))

for ax, labels, title in zip(
    axes,
    [labels_left, labels_right],
    [
        "Layout A",
        "Same geometry, different box labels",
    ],
):

    # Build the physical path:
    # start -> target 0 -> target 1 -> target 2 -> target 3
    route = np.vstack([
        start,
        targets[route_order],
    ])

    # Draw path
    ax.plot(
        route[:, 0],
        route[:, 1],
        "-o",
        linewidth=2,
        alpha=0.8,
        zorder=1,
    )

    # Start point
    ax.scatter(
        start[0],
        start[1],
        marker="*",
        s=180,
        label="Start",
        zorder=3,
    )

    # Target points
    ax.scatter(
        targets[:, 0],
        targets[:, 1],
        marker="s",
        s=100,
        zorder=3,
    )

    # Target labels
    for position, label in zip(targets, labels):
        ax.text(
            position[0] + 0.02,
            position[1] + 0.02,
            label,
            fontsize=12,
        )

    ax.set_xlim(0, 1)
    ax.set_ylim(0, 1)
    ax.set_aspect("equal")
    ax.set_xlabel("x")
    ax.set_ylabel("y")
    ax.set_title(title)
    ax.grid(alpha=0.25)

plt.suptitle(
    "Same physical layout and path, but different box labels",
    fontsize=13,
)

plt.tight_layout()
plt.show()
